# %% [markdown]
# 다양한 알고리즘을 사용해 성능을 비교해보고, 상위 3개 알고리즘에서 튜닝을 시작하겠습니다.

# %% [markdown]
# - 랜덤 포레스트(베이스)
# - 엑스트라 트리
# - XGB
# - LGBM
# - KNN
# - Ridge, Lasso, LR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import RidgeCV, LassoCV, LinearRegression, Ridge, Lasso

from bayes_opt import BayesianOptimization

from sklearn.model_selection import KFold

from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Preprocessing

# %%
PATH = r'C:\Users\Wyatt\wyatt37\data\energy'

# %%
train_col = ['num', 'date_time', 'target', 'temp', 'wind', 'humid', 'rain', 'sunny', 'cooler', 'solar']
test_col = ['num', 'date_time', 'temp', 'wind', 'humid', 'rain', 'sunny', 'cooler', 'solar']

# %%
train = pd.read_csv(PATH + '\\train.csv', encoding='cp949', names=train_col, header=0)
test = pd.read_csv(PATH + '\\test.csv', encoding='cp949', names=test_col, header=0)
sub = pd.read_csv(PATH + '\\sample_submission.csv', encoding='cp949')

# %%
def make_time(train):
    train['date_time'] = pd.to_datetime(train.date_time)
    
    # 1차 time / 지지
    train['month'] = train.date_time.dt.month                    # 월(숫자)
    train['day'] = train.date_time.dt.day                        # 일(숫자)
    train['hour'] = train.date_time.dt.hour                      # 시(숫자)
    train['weekday'] = train.date_time.dt.weekday                # 시(숫자)
    train['dayofyear'] = train.date_time.dt.dayofyear            # 연 기준 몇일째(숫자)
    train['weekofyear'] = train.date_time.dt.isocalendar().week  # 연 기준 몇주째(숫자) (=week)
    
    # 2차 time / 지지
    train['month_start'] = train.date_time.dt.is_month_start
    train['month_end'] = train.date_time.dt.is_month_end
    
    # 여기까지
    
    #train.drop(['date_time', 'datetime'], axis=1, inplace=True)
    
    train.weekofyear = train.weekofyear.astype(int)
    
    return train

# %%
train = make_time(train)
test = make_time(test)

# %%
# cooler와 solar를 넣어주겠습니다.
for i in range(1, 61):
    test.loc[test.num == i, 'cooler'] = train.loc[train.num == i, 'cooler'].mean()
    test.loc[test.num == i, 'solar'] = train.loc[train.num == i, 'solar'].mean()

# %%
test[['temp', 'wind', 'humid', 'rain', 'sunny']] = test[['temp', 'wind', 'humid', 'rain', 'sunny']].interpolate(method='values').round(1)

# %%
# 6월 6일은 현충일
# 8월 15일은 광복절
# 8월 17일은 임시공휴일

# 휴일이 많지 않으니, 주말에 포함시키자.

train.loc[train.weekday >= 5, 'holiday'] = True
train.loc[train.weekday < 5, 'holiday'] = False
train.loc[(train.month == 8) & (train.day == 17), 'holiday'] = True

test.loc[test.weekday >= 5, 'holiday'] = True
test.loc[test.weekday < 5, 'holiday'] = False

train.holiday = train.holiday.astype('bool')
test.holiday = test.holiday.astype('bool')

# %%
train
# Out:
#         num           date_time    target  temp  wind  humid  rain  sunny  \
# 0         1 2020-06-01 00:00:00  8179.056  17.6   2.5   92.0   0.8    0.0
# 1         1 2020-06-01 01:00:00  8135.640  17.7   2.9   91.0   0.3    0.0
# 2         1 2020-06-01 02:00:00  8107.128  17.5   3.2   91.0   0.0    0.0
# 3         1 2020-06-01 03:00:00  8048.808  17.1   3.2   91.0   0.0    0.0
# 4         1 2020-06-01 04:00:00  8043.624  17.0   3.3   92.0   0.0    0.0
# ...     ...                 ...       ...   ...   ...    ...   ...    ...
# 122395   60 2020-08-24 19:00:00  4114.368  27.8   2.3   68.0   0.0    0.7
# 122396   60 2020-08-24 20:00:00  3975.696  27.3   1.2   71.0   0.0    0.0
# 122397   60 2020-08-24 21:00:00  3572.208  27.3   1.8   71.0   0.0    0.0
# 122398   60 2020-08-24 22:00:00  3299.184  27.1   1.8   74.0   0.0    0.0
# 122399   60 2020-08-24 23:00:00  3204.576  27.1   2.6   75.0   0.0    0.0
#
#         cooler  solar  month  day  hour  weekday  dayofyear  weekofyear  \
# 0          0.0    0.0      6    1     0        0        153          23
# 1          0.0    0.0      6    1     1        0        153          23
# 2          0.0    0.0      6    1     2        0        153          23
# 3          0.0    0.0      6    1     3        0        153          23
# 4          0.0    0.0      6    1     4        0        153          23
# ...        ...    ...    ...  ...   ...      ...        ...         ...
# 122395     1.0    1.0      8   24    19        0        237          35
# 122396     1.0    1.0      8   24    20        0        237          35
# 122397     1.0    1.0      8   24    21        0        237          35
# 122398     1.0    1.0      8   24    22        0        237          35
# 122399     1.0    1.0      8   24    23        0        237          35
#
#         month_start  month_end  holiday
# 0              True      False    False
# 1              True      False    False
# 2              True      False    False
# 3              True      False    False
# 4              True      False    False
# ...             ...        ...      ...
# 122395        False      False    False
# 122396        False      False    False
# 122397        False      False    False
# 122398        False      False    False
# 122399        False      False    False
#
# [122400 rows x 19 columns]

# %% [markdown]
# ## train_test_split

# %%
x_train = train.loc[train.date_time < '2020-08-18', ~train.columns.isin(['target', 'date_time'])]
y_train = train.loc[train.date_time < '2020-08-18'][['num', 'target']]
x_test = train.loc[train.date_time >= '2020-08-18', ~train.columns.isin(['target', 'date_time'])]
y_test = train.loc[train.date_time >= '2020-08-18'][['num', 'target']]

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((112320, 17), (112320, 2), (10080, 17), (10080, 2))

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['x_train_{}'.format(i)] = x_train.loc[x_train.num == i, ~x_train.columns.isin(['num', 'cooler', 'solar'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['y_train_{}'.format(i)] = y_train.loc[y_train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['x_test_{}'.format(i)] = x_test.loc[x_test.num == i, ~x_test.columns.isin(['num', 'cooler', 'solar'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['y_test_{}'.format(i)] = y_test.loc[y_test.num == i, 'target']

# %%
x_train_60.shape, y_train_60.shape, x_test_60.shape, y_test_60.shape
# Out:
# ((1872, 14), (1872,), (168, 14), (168,))

# %% [markdown]
# ## Metric

# %%
# metric
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred)))*100

# %% [markdown]
# ## Random Forest(Base)

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in tqdm(range(1, 61)):
    model = RandomForestRegressor(random_state=42, oob_score=True)
    model.fit(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)])
    pred = model.predict(globals()['x_test_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:36<00:00,  1.65it/s]

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (57.072131631633866, 198.97561335920895)

# %% [markdown]
# 데이터 타입이 object임에도, 값이 True/Flase면 랜포는 불리언으로 알아먹는다.

# %%
score_df = pd.DataFrame(scores, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')


plt.show()

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## Extra Trees

# %% [markdown]
# ### Bootstrap=True

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in tqdm(range(1, 61)):
    model = ExtraTreesRegressor(random_state=42, bootstrap=True ,oob_score=True)
    model.fit(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)])
    pred = model.predict(globals()['x_test_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:21<00:00,  2.86it/s]

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (56.804123982937725, 188.2261855348892)

# %%
score_df = pd.DataFrame(scores, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')


plt.show()

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ### Bootstrap=False

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in tqdm(range(1, 61)):
    model = ExtraTreesRegressor(random_state=42)
    model.fit(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)])
    pred = model.predict(globals()['x_test_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    #oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:24<00:00,  2.40it/s]

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (0.0, 185.70091087065805)

# %%
score_df = pd.DataFrame(scores, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')


plt.show()

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## LGBM

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in range(1, 61):
    print(i, '번째 모델---------------------------------------------------------------------')    
    cross = KFold(n_splits=5, shuffle=True, random_state=42)
    folds = []
    for train_idx, valid_idx in cross.split(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)]):
        folds.append((train_idx, valid_idx))
        
    models={}
    for fold in range(5):
        train_idx, valid_idx = folds[fold]
        X_tra = globals()['x_train_{}'.format(i)].iloc[train_idx, :]
        y_tra = globals()['y_train_{}'.format(i)].iloc[train_idx]
        X_val = globals()['x_train_{}'.format(i)].iloc[valid_idx, :]
        y_val = globals()['y_train_{}'.format(i)].iloc[valid_idx]

        model=LGBMRegressor(learning_rate=0.027, random_state=42, n_estimators=1000)
        model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
                  eval_metric='smape',
                  early_stopping_rounds=30, verbose=1000)
        models[fold]=model
    
    for k in range(5):
        pred += models[k].predict(globals()['x_test_{}'.format(i)])/5 
    
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    #oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 1 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [380]	training's l2: 340.484	valid_1's l2: 815.52
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [653]	training's l2: 264.208	valid_1's l2: 553.531
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [647]	training's l2: 97.58	valid_1's l2: 1959.21
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [383]	training's l2: 352.953	valid_1's l2: 715.922
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [394]	training's l2: 363.367	valid_1's l2: 535.885
# 2 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [656]	training's l2: 178.302	valid_1's l2: 1103.34
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [539]	training's l2: 209.916	valid_1's l2: 983.511
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [575]	training's l2: 187.178	valid_1's l2: 1337.79
# Training until validation scores don't improve for 30 rounds
# Early stopping, best iteration is:
# [362]	training's l2: 340.754	valid_1's l2: 1217.55
# Training until validation scores don't improve for 30 rounds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-cc5976c501fb> in <module>
#      19
#      20         model=LGBMRegressor(learning_rate=0.027, random_state=42, n_estimators=1000)
# ---> 21         model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
#      22                   eval_metric='smape',
#      23                   early_stopping_rounds=30, verbose=1000)
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     816             callbacks=None, init_model=None):
#     817         """Docstring is inherited from the LGBMModel."""
# --> 818         super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#     819                     eval_set=eval_set, eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     820                     eval_init_score=eval_init_score, eval_metric=eval_metric,
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     681             init_model = init_model.booster_
#     682
# --> 683         self._Booster = train(params, train_set,
#     684                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     685                               early_stopping_rounds=early_stopping_rounds,
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    2641             if self.__set_objective_to_none:
#    2642                 raise LightGBMError('Cannot update due to null objective function.')
# -> 2643             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    2644                 self.handle,
#    2645                 ctypes.byref(is_finished)))
#
# KeyboardInterrupt:

# %%
np.sum(scores)
# Out:
# 5920.551983672165

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in tqdm(range(1, 61)):
    
    model = LGBMRegressor(random_state=42, **params)
    model.fit(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)])
    pred = model.predict(globals()['x_test_{}'.format(i)])
    
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    #oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:05<00:00, 11.55it/s]

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (0.0, 205.39853780141675)

# %%
score_df = pd.DataFrame(scores, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')


plt.show()

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## XGB

# %%
preds = []
fe = []
#oob_scores = []
scores = []
for i in range(1, 61):
    print(i, '번째 모델---------------------------------------------------------------------')    
    cross = KFold(n_splits=5, shuffle=True, random_state=42)
    folds = []
    for train_idx, valid_idx in cross.split(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)]):
        folds.append((train_idx, valid_idx))
        
    models={}
    for fold in range(5):
        train_idx, valid_idx = folds[fold]
        X_tra = globals()['x_train_{}'.format(i)].iloc[train_idx, :]
        y_tra = globals()['y_train_{}'.format(i)].iloc[train_idx]
        X_val = globals()['x_train_{}'.format(i)].iloc[valid_idx, :]
        y_val = globals()['y_train_{}'.format(i)].iloc[valid_idx]

        model=XGBRegressor(learning_rate=0.027, random_state=42, n_estimators=1000)
        model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
                  eval_metric='rmse',
                  early_stopping_rounds=30, verbose=1000)
        models[fold]=model
    
    for k in range(5):
        pred += models[k].predict(globals()['x_test_{}'.format(i)])/5 
    
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    #oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 1 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:8301.91992	validation_1-rmse:8315.87109
# [388]	validation_0-rmse:13.23268	validation_1-rmse:34.21402
# [0]	validation_0-rmse:8304.13867	validation_1-rmse:8306.73340
# [999]	validation_0-rmse:6.25720	validation_1-rmse:21.87797
# [0]	validation_0-rmse:8307.21094	validation_1-rmse:8293.97949
# [384]	validation_0-rmse:12.42401	validation_1-rmse:44.72276
# [0]	validation_0-rmse:8306.53809	validation_1-rmse:8296.77832
# [484]	validation_0-rmse:11.01063	validation_1-rmse:31.86741
# [0]	validation_0-rmse:8303.39941	validation_1-rmse:8309.79102
# [636]	validation_0-rmse:9.29520	validation_1-rmse:22.39728
# 2 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:1299.00439	validation_1-rmse:1276.99206
# [591]	validation_0-rmse:13.50987	validation_1-rmse:32.04798
# [0]	validation_0-rmse:1295.01404	validation_1-rmse:1293.07959
# [717]	validation_0-rmse:11.70435	validation_1-rmse:31.97959
# [0]	validation_0-rmse:1293.32251	validation_1-rmse:1299.49121
# [648]	validation_0-rmse:12.28262	validation_1-rmse:35.26084
# [0]	validation_0-rmse:1290.82373	validation_1-rmse:1309.23059
# [337]	validation_0-rmse:18.96995	validation_1-rmse:35.46989
# [0]	validation_0-rmse:1294.69775	validation_1-rmse:1294.04004
# [396]	validation_0-rmse:16.71165	validation_1-rmse:34.32549
# 3 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse
번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:5787.09522	validation_1-rmse:5798.88770
# [322]	validation_0-rmse:20.53332	validation_1-rmse:84.33216
# [0]	validation_0-rmse:5790.78272	validation_1-rmse:5783.69922
# [433]	validation_0-rmse:16.49843	validation_1-rmse:85.18411
# [0]	validation_0-rmse:5789.60352	validation_1-rmse:5788.55127
# [230]	validation_0-rmse:31.16115	validation_1-rmse:117.13554
# [0]	validation_0-rmse:5790.34717	validation_1-rmse:5785.37012
# [742]	validation_0-rmse:9.39860	validation_1-rmse:203.64333
# [0]	validation_0-rmse:5789.14648	validation_1-rmse:5790.44727
# [789]	validation_0-rmse:9.15529	validation_1-rmse:30.58917
# 32 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:2336.17358	validation_1-rmse:2335.20752
# [608]	validation_0-rmse:4.09578	validation_1-rmse:8.66357
# [0]	validation_0-rmse:2336.24219	validation_1-rmse:2334.92529
# [900]	validation_0-rmse:3.01643	validation_1-rmse:8.64877
# [0]	validation_0-rmse:2336.04517	validation_1-rmse:2335.73731
# [534]	validation_0-rmse:4.33597	validation_1-rmse:9.46303
# [0]	validation_0-rmse:2335.25293	validation_1-rmse:2339.01782
# [539]	validation_0-rmse:4.27647	validation_1-rmse:9.32414
# [0]	validation_0-rmse:2336.21313	validation_1-rmse:2335.04102
# [714]	validation_0-rmse:3.48874	validation_1-rmse:9.08859
# 33 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:2512.39233	validation_1-rmse:2504.98218
# [620]	validation_0-rmse:6.37937	validation_1-rmse:18.01421
# [0]	validation_0-rmse:2510.53687	validation_1-rmse:2512.64380
# [528]	validation_0-rmse:7.24434	validation_1-rmse:22.63361
# [0]	validation_0-rmse:2509.94605	validation_1-rmse:2515.10010
# [203]	validation_0-rmse:21.59754	validation_1-rmse:60.88953
# [0]	validation_0-rmse:2510.57227	validation_1-rmse:2512.46020
# [255]	validation_0-rmse:11.80348	validation_1-rmse:96.95771
# [0]	validation_0-rmse:2511.28687	validation_1-rmse:2509.54834
# [211]	validation_0-rmse:20.92868	validation_1-rmse:42.39336
# 34 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:942.65601	validation_1-rmse:938.77136
# [949]	validation_0-rmse:13.55149	validation_1-rmse:117.01904
# [0]	validation_0-rmse:942.66394	validation_1-rmse:938.99915
# [412]	validation_0-rmse:34.09727	validation_1-rmse:117.30885
# [0]	validation_0-rmse:944.49554	validation_1-rmse:930.78296
# [431]	validation_0-rmse:32.29872	validation_1-rmse:120.25970
# [0]	validation_0-rmse:942.12744	validation_1-rmse:940.86725
# [421]	validation_0-rmse:33.94376	validation_1-rmse:109.41720
# [0]	validation_0-rmse:937.31677	validation_1-rmse:960.40002
# [861]	validation_0-rmse:14.45095	validation_1-rmse:87.93425
# 35 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:
번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:6752.89941	validation_1-rmse:6648.85693
# [631]	validation_0-rmse:51.00928	validation_1-rmse:152.42603
# [0]	validation_0-rmse:6738.49170	validation_1-rmse:6706.68994
# [699]	validation_0-rmse:49.54313	validation_1-rmse:142.26469
# [0]	validation_0-rmse:6729.67627	validation_1-rmse:6741.30176
# [999]	validation_0-rmse:33.80693	validation_1-rmse:150.87039
# [0]	validation_0-rmse:6712.45508	validation_1-rmse:6811.22461
# [526]	validation_0-rmse:61.29031	validation_1-rmse:130.36256
# [0]	validation_0-rmse:6727.25781	validation_1-rmse:6751.94629
# [882]	validation_0-rmse:38.65084	validation_1-rmse:165.74927
# 55 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:2115.21118	validation_1-rmse:2082.61548
# [756]	validation_0-rmse:17.75088	validation_1-rmse:60.61968
# [0]	validation_0-rmse:2109.58862	validation_1-rmse:2104.77441
# [584]	validation_0-rmse:22.46093	validation_1-rmse:71.12594
# [0]	validation_0-rmse:2110.32153	validation_1-rmse:2102.06982
# [622]	validation_0-rmse:19.55908	validation_1-rmse:68.79001
# [0]	validation_0-rmse:2099.77051	validation_1-rmse:2143.99170
# [705]	validation_0-rmse:19.12572	validation_1-rmse:70.28629
# [0]	validation_0-rmse:2108.40942	validation_1-rmse:2110.02393
# [914]	validation_0-rmse:13.01497	validation_1-rmse:78.17385
# 56 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:703.81012	validation_1-rmse:697.28552
# [458]	validation_0-rmse:13.46870	validation_1-rmse:30.83081
# [0]	validation_0-rmse:701.49115	validation_1-rmse:706.27216
# [653]	validation_0-rmse:9.64452	validation_1-rmse:32.56263
# [0]	validation_0-rmse:702.91443	validation_1-rmse:700.57037
# [861]	validation_0-rmse:8.17342	validation_1-rmse:29.86333
# [0]	validation_0-rmse:701.10651	validation_1-rmse:707.41486
# [999]	validation_0-rmse:6.74412	validation_1-rmse:33.23949
# [0]	validation_0-rmse:702.92450	validation_1-rmse:700.71301
# [596]	validation_0-rmse:10.48980	validation_1-rmse:35.43801
# 57 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:2567.17065	validation_1-rmse:2540.22168
# [999]	validation_0-rmse:29.42945	validation_1-rmse:123.95094
# [0]	validation_0-rmse:2564.75708	validation_1-rmse:2550.21655
# [668]	validation_0-rmse:39.86617	validation_1-rmse:140.89546
# [0]	validation_0-rmse:2552.94605	validation_1-rmse:2598.03589
# [999]	validation_0-rmse:24.76857	validation_1-rmse:131.65366
# [0]	validation_0-rmse:2563.69116	validation_1-rmse:2553.90405
# [979]	validation_0-rmse:27.01981	validation_1-rmse:126.39717
# [0]	validation_0-rmse:2560.81909	validation_1-rmse:2566.11914
# [805]	validation_0-rmse:34.73260	validation_1-rmse:125.92275
# 58 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:926.19086	validation_1-rmse:899.09424
# [873]	validation_0-rmse:7.51245	validation_1-rmse:35.10221
# [0]	validation_0-rmse:922.19983	validation_1-rmse:915.23712
# [684]	validation_0-rmse:10.00217	validation_1-rmse:27.31631
# [0]	validation_0-rmse:920.69623	validation_1-rmse:921.17999
# [999]	validation_0-rmse:7.65317	validation_1-rmse:26.35712
# [0]	validation_0-rmse:915.00909	validation_1-rmse:943.84912
# [717]	validation_0-rmse:10.02279	validation_1-rmse:29.31765
# [0]	validation_0-rmse:920.00989	validation_1-rmse:924.25580
# [993]	validation_0-rmse:7.61038	validation_1-rmse:28.49624
# 59 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:1058.62830	validation_1-rmse:1048.48279
# [183]	validation_0-rmse:107.89123	validation_1-rmse:154.19106
# [0]	validation_0-rmse:1056.29517	validation_1-rmse:1058.67432
# [210]	validation_0-rmse:101.94430	validation_1-rmse:156.45692
# [0]	validation_0-rmse:1056.75195	validation_1-rmse:1056.45935
# [200]	validation_0-rmse:102.17574	validation_1-rmse:154.27914
# [0]	validation_0-rmse:1053.72375	validation_1-rmse:1068.78284
# [200]	validation_0-rmse:101.25063	validation_1-rmse:159.25977
# [0]	validation_0-rmse:1057.93787	validation_1-rmse:1050.95129
# [178]	validation_0-rmse:105.44390	validation_1-rmse:151.07298
# 60 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:3265.65259	validation_1-rmse:3252.94507
# [337]	validation_0-rmse:58.27180	validation_1-rmse:116.76805
# [0]	validation_0-rmse:3265.14746	validation_1-rmse:3255.29394
# [467]	validation_0-rmse:50.28521	validation_1-rmse:121.42760
# [0]	validation_0-rmse:3267.47461	validation_1-rmse:3245.31665
# [397]	validation_0-rmse:57.50209	validation_1-rmse:121.74307
# [0]	validation_0-rmse:3254.88452	validation_1-rmse:3296.55493
# [358]	validation_0-rmse:59.37249	validation_1-rmse:119.59304
# [0]	validation_0-rmse:3262.56860	validation_1-rmse:3265.44263
# [289]	validation_0-rmse:65.04938	validation_1-rmse:121.74036

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (0.0, 5470.573453364873)

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in tqdm(range(1, 61)):
    model = XGBRegressor(random_state=42)
    model.fit(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)])
    pred = model.predict(globals()['x_test_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    #oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:10<00:00,  5.89it/s]

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (0.0, 211.81447945017482)

# %%
score_df = pd.DataFrame(scores, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')


plt.show()

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## RidgeCV

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in tqdm(range(1, 61)):
    model = Ridge(normalize=True, alpha=1.)
    model.fit(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)])
    pred = model.predict(globals()['x_test_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(model.coef_)
    #oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 204.09it/s]

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (0.0, 641.6544899745163)

# %%
score_df = pd.DataFrame(scores, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')


plt.show()

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## LassoCV

# %%
preds = []
fe = []
oob_scores = []
scores = []
for i in tqdm(range(1, 61)):
    model = Lasso(normalize=True, alpha=1.)
    model.fit(globals()['x_train_{}'.format(i)], globals()['y_train_{}'.format(i)])
    pred = model.predict(globals()['x_test_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(model.coef_)
    #oob_scores.append(model.oob_score_)
    scores.append(SMAPE(globals()['y_test_{}'.format(i)], pred))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 163.04it/s]

# %%
np.sum(oob_scores), np.sum(scores)
# Out:
# (0.0, 602.4355021910519)

# %%
score_df = pd.DataFrame(scores, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')


plt.show()

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## Parameter Tuning

# %% [markdown]
# ### Bayes Search

# %%
# metric
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred)))*100

# %% [markdown]
# 참고: https://wooono.tistory.com/102

# %% [markdown]
# 학습용 데이터 셋을 먼저 만들어 주고, 테스트용 데이터 셋을 따로 또 만들어 줍니다.

# %%
x_train = train.loc[train.date_time < '2020-08-18', ~train.columns.isin(['target', 'date_time'])]
y_train = train.loc[train.date_time < '2020-08-18'][['num', 'target']]
x_test = train.loc[train.date_time >= '2020-08-18', ~train.columns.isin(['target', 'date_time'])]
y_test = train.loc[train.date_time >= '2020-08-18'][['num', 'target']]

# %% [markdown]
# #### 최고

# %%
#목적함수 생성
def rf_cv(n_estimators):
    
    model = RandomForestRegressor(n_estimators = int(round(n_estimators)),
                                  random_state=42,
                                  n_jobs=-1)
    
    # 모델 훈련
    model.fit(x_train_bo, y_train_bo)

    # 예측값 출력
    y_pred= model.predict(x_test_bo)

    # metric 계산
    smape = SMAPE(y_test_bo, y_pred)

    # 오차 최적화로 사용할 metric 반환
    return -smape

# %%
pbounds = {'n_estimators' : (50, 500)}

# %%
# 결과물을 적재할 컨테이너를 만듭니다.
preds = []
fe = []
params = []
models = []
targets = []
oob_scores = []

for i in tqdm(range(1, 61)):
    # 베이즈옵트를 위한 train_test set 을 만듭니다.
    x_train_bo = x_train.loc[x_train.num == i, ~x_train.columns.isin(['num', 'cooler', 'solar'])]
    y_train_bo = y_train.loc[y_train.num == i, 'target']
    x_test_bo = x_test.loc[x_test.num == i, ~x_test.columns.isin(['num', 'cooler', 'solar'])]
    y_test_bo = y_test.loc[y_test.num == i, 'target']
    
    # 예측을 위한 train_test set을 만듭니다.
    x_train_building = train.loc[train.num == i, ~train.columns.isin(['target', 'num', 'cooler', 'solar', 'date_time'])]
    y_train_building = train.loc[train.num == i, 'target']
    x_test_building = test.loc[test.num == i, ~test.columns.isin(['num', 'cooler', 'solar', 'date_time'])]
    
    # 베이즈 옵트를 통해 최적화된 하이퍼 파라미터를 추출합니다.
    bo = BayesianOptimization(f = rf_cv, pbounds = pbounds, verbose = 0, random_state = 0 )
    bo.maximize(init_points=10, n_iter = 20, acq='ei', xi=0.01)
    best_params = bo.max['params']
    best_target = abs(bo.max['target'])
    
    # 하이퍼 파라미터가 소수점으로 되어 있으므로, rounding을 해줍니다.
    for k, v in best_params.items():
        best_params[k] = round(v)
    
    # 최적화된 하이퍼 파라미터로 모델을 생성하고 학습합니다.
    model = RandomForestRegressor(**best_params, oob_score=True ,random_state=42)
    model.fit(x_train_building, y_train_building)
    pred = model.predict(x_test_building)
    
    # 결과물을 적재해줍니다.
    models.append(model)
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    params.append(best_params)
    targets.append(best_target)
    oob_scores.append(model.oob_score_)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [16:14<00:00, 16.25s/it]

# %%
score_df = pd.DataFrame(targets, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')
plt.show()

# %%
np.sum(oob_scores)
# Out:
# 57.155972352232816

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub.to_csv('submission/210611_bo3-rf.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8675.225705
# 1       1 2020-08-25 01  8672.042361
# 2       1 2020-08-25 02  8668.667803
# 3       1 2020-08-25 03  8663.823738
# 4       1 2020-08-25 04  8655.576787
# ...                 ...          ...
# 10075  60 2020-08-31 19  4063.386240
# 10076  60 2020-08-31 20  4014.581760
# 10077  60 2020-08-31 21  3796.577280
# 10078  60 2020-08-31 22  3522.746880
# 10079  60 2020-08-31 23  3376.650240
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_building.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.02+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# #### 재현

# %%
pbounds = {'n_estimators' : (50, 500)}

# %%
#목적함수 생성
def rf_cv(n_estimators):
    
    model = RandomForestRegressor(n_estimators = int(round(n_estimators)),
                                  random_state=42,
                                  n_jobs=-1)
    
    # 모델 훈련
    model.fit(x_train_bo, y_train_bo)

    # 예측값 출력
    y_pred= model.predict(x_test_bo)

    # metric 계산
    smape = SMAPE(y_test_bo, y_pred)

    # 오차 최적화로 사용할 metric 반환
    return -smape

# %%
# 결과물을 적재할 컨테이너를 만듭니다.
preds = []
fe = []
params = []
models = []
targets = []
oob_scores = []

for i in tqdm(range(1, 61)):
    # 베이즈옵트를 위한 train_test set 을 만듭니다.
    x_train_bo = x_train.loc[x_train.num == i, ~x_train.columns.isin(['num', 'cooler', 'solar'])]
    y_train_bo = y_train.loc[y_train.num == i, 'target']
    x_test_bo = x_test.loc[x_test.num == i, ~x_test.columns.isin(['num', 'cooler', 'solar'])]
    y_test_bo = y_test.loc[y_test.num == i, 'target']
    
    # 예측을 위한 train_test set을 만듭니다.
    x_train_building = train.loc[train.num == i, ~train.columns.isin(['target', 'num', 'cooler', 'solar', 'date_time'])]
    y_train_building = train.loc[train.num == i, 'target']
    x_test_building = test.loc[test.num == i, ~test.columns.isin(['num', 'cooler', 'solar', 'date_time'])]
    
    # 베이즈 옵트를 통해 최적화된 하이퍼 파라미터를 추출합니다.
    bo = BayesianOptimization(f = rf_cv, pbounds = pbounds, verbose = 0, random_state = 0 )
    bo.maximize(init_points=10, n_iter = 20, acq='ei', xi=0.01)
    best_params = bo.max['params']
    best_target = abs(bo.max['target'])
    
    # 하이퍼 파라미터가 소수점으로 되어 있으므로, rounding을 해줍니다.
    for k, v in best_params.items():
        best_params[k] = round(v)
    
    # 최적화된 하이퍼 파라미터로 모델을 생성하고 학습합니다.
    model = RandomForestRegressor(**best_params, oob_score=True ,random_state=42)
    model.fit(x_train_building, y_train_building)
    pred = model.predict(x_test_building)
    
    # 결과물을 적재해줍니다.
    models.append(model)
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    params.append(best_params)
    targets.append(best_target)
    oob_scores.append(model.oob_score_)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [19:10<00:00, 19.17s/it]

# %%
np.sum(oob_scores)
# Out:
# 57.155972352232816

# %%
preds = sum(preds, [])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-52e2b67446f7> in <module>
# ----> 1 preds = sum(preds, [])
#
# TypeError: can only concatenate list (not "float") to list

# %%
sub.answer = preds

# %%
#sub.to_csv('submission/210611_bo3-rf.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8675.225705
# 1       1 2020-08-25 01  8672.042361
# 2       1 2020-08-25 02  8668.667803
# 3       1 2020-08-25 03  8663.823738
# 4       1 2020-08-25 04  8655.576787
# ...                 ...          ...
# 10075  60 2020-08-31 19  4063.386240
# 10076  60 2020-08-31 20  4014.581760
# 10077  60 2020-08-31 21  3796.577280
# 10078  60 2020-08-31 22  3522.746880
# 10079  60 2020-08-31 23  3376.650240
#
# [10080 rows x 2 columns]

# %% [markdown]
# #### 도전

# %%
pbounds = {'min_samples_split' : (10, 1000),
           'min_samples_leaf': (10, 1000),
           'max_features': (3, 14),
           'max_depth': (3, 15)}

# %%
# 탐색 대상 함수 (XGBRegressor)
def XGB_cv(max_depth, learning_rate, n_estimators, gamma, min_child_weight, subsample ,colsample_bytree,
           silent=True, nthread=-1):

    # 모델 정의
    model = XGBRegressor(max_depth=int(max_depth),
                         learning_rate=learning_rate,
                         n_estimators=int(n_estimators),
                         gamma=gamma,
                         min_child_weight=min_child_weight,
                         subsample=subsample,
                         colsample_bytree=colsample_bytree, 
                         nthread=nthread
                         )
    # 모델 훈련
    model.fit(x_train_bo, y_train_bo)

    # 예측값 출력
    y_pred= model.predict(x_test_bo)

    # metric 계산
    smape = SMAPE(y_test_bo, y_pred)

    # 오차 최적화로 사용할 metric 반환
    return -smape

# %%
# 결과물을 적재할 컨테이너를 만듭니다.
preds = []
fe = []
params = []
models = []
targets = []
oob_scores = []

for i in tqdm(range(1, 61)):
    # 베이즈옵트를 위한 train_test set 을 만듭니다.
    x_train_bo = x_train.loc[x_train.num == i, ~x_train.columns.isin(['num', 'cooler', 'solar'])]
    y_train_bo = y_train.loc[y_train.num == i, 'target']
    x_test_bo = x_test.loc[x_test.num == i, ~x_test.columns.isin(['num', 'cooler', 'solar'])]
    y_test_bo = y_test.loc[y_test.num == i, 'target']
    
    # 예측을 위한 train_test set을 만듭니다.
    x_train_building = train.loc[train.num == i, ~train.columns.isin(['target', 'num', 'cooler', 'solar', 'date_time'])]
    y_train_building = train.loc[train.num == i, 'target']
    x_test_building = test.loc[test.num == i, ~test.columns.isin(['num', 'cooler', 'solar', 'date_time'])]
    
    # 베이즈 옵트를 통해 최적화된 하이퍼 파라미터를 추출합니다.
    bo = BayesianOptimization(f = rf_cv, pbounds = pbounds, verbose = 0, random_state = 0 )
    bo.maximize(init_points=10, n_iter = 20, acq='ei', xi=0.01)
    best_params = bo.max['params']
    best_target = abs(bo.max['target'])
    
    # 하이퍼 파라미터가 소수점으로 되어 있으므로, rounding을 해줍니다.
    for k, v in best_params.items():
        best_params[k] = round(v)
    
    # 최적화된 하이퍼 파라미터로 모델을 생성하고 학습합니다.
    model = RandomForestRegressor(**best_params, oob_score=True ,random_state=42)
    model.fit(x_train_building, y_train_building)
    pred = model.predict(x_test_building)
    
    # 결과물을 적재해줍니다.
    models.append(model)
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    params.append(best_params)
    targets.append(best_target)
    oob_scores.append(model.oob_score_)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [07:07<00:00,  7.13s/it]

# %%
score_df = pd.DataFrame(targets, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')
plt.show()

# %%
np.sum(oob_scores)
# Out:
# 52.7941093740854

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub.to_csv('submission/210611_bo4-rf.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8668.490148
# 1       1 2020-08-25 01  8666.489666
# 2       1 2020-08-25 02  8661.655425
# 3       1 2020-08-25 03  8652.240317
# 4       1 2020-08-25 04  8648.353996
# ...                 ...          ...
# 10075  60 2020-08-31 19  4103.715842
# 10076  60 2020-08-31 20  4056.211223
# 10077  60 2020-08-31 21  3653.977940
# 10078  60 2020-08-31 22  3629.473596
# 10079  60 2020-08-31 23  3629.473596
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_building.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.02+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# #### sample

# %%
# 탐색 대상 함수 (XGBRegressor)
def RF_cv(n_estimators, max_depth):

    # 모델 정의
    model = RandomForestRegressor(n_estimators=int(n_estimators),
                                 max_depth=int(max_depth),
                                 random_state=42,
                                 n_jobs=-1)
    # 모델 훈련
    model.fit(x_train, y_train)

    # 예측값 출력
    y_pred= model.predict(x_test)

    # metric 계산
    smape = SMAPE(y_test, y_pred)

    # 오차 최적화로 사용할 metric 반환
    return -smape

# %%
#  bayesian-optimization 라이브러리의 BayesianOptimization 클래스 import
from bayes_opt import BayesianOptimization
import numpy as np

# 실험해보고자하는 hyperparameter 집합
pbounds = {'n_estimators': (100, 2000),
           'max_depth': (3, 15)
          }

# Bayesian optimization 객체 생성
# f : 탐색 대상 함수, pbounds : hyperparameter 집합
# verbose = 2 항상 출력, verbose = 1 최댓값일 때 출력, verbose = 0 출력 안함
# random_state : Bayesian Optimization 상의 랜덤성이 존재하는 부분을 통제 
bo=BayesianOptimization(f=RF_cv, pbounds=pbounds, verbose=2, random_state=42)    

# 메소드를 이용해 최대화 과정 수행
# init_points :  초기 Random Search 갯수
# n_iter : 반복 횟수 (몇개의 입력값-함숫값 점들을 확인할지! 많을 수록 정확한 값을 얻을 수 있다.)
# acq : Acquisition Function들 중 Expected Improvement(EI) 를 사용
# xi : exploration 강도 (기본값은 0.0)
bo.maximize(init_points=2, n_iter=10, acq='ei', xi=0.01)

# ‘iter’는 반복 회차, ‘target’은 목적 함수의 값, 나머지는 입력값을 나타냅니다. 
# 현재 회차 이전까지 조사된 함숫값들과 비교하여, 현재 회차에 최댓값이 얻어진 경우, 
# bayesian-optimization 라이브러리는 이를 자동으로 다른 색 글자로 표시하는 것을 확인할 수 있습니다

# 찾은 파라미터 값 확인
print(bo.max)
# Out:
# |   iter    |  target   | max_depth | n_esti... |
# -------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\envs\wyatt38\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     190         try:
# --> 191             target = self._cache[_hashable(x)]
#     192         except KeyError:
#
# KeyError: (7.49448142616835, 1906.3571821788407)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-251-86066974e0fc> in <module>
#      19 # acq : Acquisition Function들 중 Expected Improvement(EI) 를 사용
#      20 # xi : exploration 강도 (기본값은 0.0)
# ---> 21 bo.maximize(init_points=2, n_iter=10, acq='ei', xi=0.01)
#      22
#      23 # ‘iter’는 반복 회차, ‘target’은 목적 함수의 값, 나머지는 입력값을 나타냅니다.
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\bayes_opt\bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     183                 iteration += 1
#     184
# --> 185             self.probe(x_probe, lazy=False)
#     186
#     187             if self._bounds_transformer:
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\bayes_opt\bayesian_optimization.py in probe(self, params, lazy)
#     114             self._queue.add(params)
#     115         else:
# --> 116             self._space.probe(params)
#     117             self.dispatch(Events.OPTIMIZATION_STEP)
#     118
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\bayes_opt\target_space.py in probe(self, params)
#     193             params = dict(zip(self._keys, x))
#     194             target = self.target_func(**params)
# --> 195             self.register(x, target)
#     196         return target
#     197
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\bayes_opt\target_space.py in register(self, params, target)
#     165
#     166         self._params = np.concatenate([self._params, x.reshape(1, -1)])
# --> 167         self._target = np.concatenate([self._target, [target]])
#     168
#     169     def probe(self, params):
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
import xgboost as xgb

# metric
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred)))*100

# 탐색 대상 함수 (XGBRegressor)
def XGB_cv(max_depth, learning_rate, n_estimators, gamma, min_child_weight, subsample ,colsample_bytree,
           silent=True, nthread=-1):

    # 모델 정의
    model = xgb.XGBRegressor(max_depth=int(max_depth),
                            learning_rate=learning_rate,
                            n_estimators=int(n_estimators),
                            gamma=gamma,
                            min_child_weight=min_child_weight,
                            subsample=subsample,
                            colsample_bytree=colsample_bytree, 
                            nthread=nthread
                            )
    # 모델 훈련
    model.fit(x_train_4, y_train_4)

    # 예측값 출력
    y_pred= model.predict(x_test_4)

    # metric 계산
    smape = SMAPE(y_test_4, y_pred)

    # 오차 최적화로 사용할 metric 반환
    return -smape

# %%
bo.max['params']
# Out:
# {'colsample_bytree': 0.9810609591803319,
#  'gamma': 59.43990020582972,
#  'learning_rate': 0.15643914910740106,
#  'max_depth': 4.016990709379462,
#  'min_child_weight': 0.9820996416351506,
#  'n_estimators': 8338.776986561905,
#  'subsample': 0.7553350142558128}

# %%
BayesianOptimization?
# Out:
# Init signature:
# BayesianOptimization(
#     f,
#     pbounds,
#     random_state=None,
#     verbose=2,
#     bounds_transformer=None,
# )
# Docstring:
# Inspired/Taken from
#     https://www.protechtraining.com/blog/post/879#simple-observer
# File:           c:\users\wyatt\miniconda3\envs\wyatt38\lib\site-packages\bayes_opt\bayesian_optimization.py
# Type:           type
# Subclasses:

# %%
from sklearn.model_selection import GridSearchCV

# %%
RandomForestRegressor?
# Out:
# Init signature:
# RandomForestRegressor(
#     n_estimators=100,
#     *,
#     criterion='mse',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features='auto',
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     min_impurity_split=None,
#     bootstrap=True,
#     oob_score=False,
#     n_jobs=None,
#     random_state=None,
#     verbose=0,
#     warm_start=False,
#     ccp_alpha=0.0,
#     max_samples=None,
# )
# Docstring:
# A random forest regressor.
#
# A random forest is a meta estimator that fits a number of classifying
# decision trees on various sub-samples of the dataset and uses averaging
# to improve the predictive accuracy and control over-fitting.
# The sub-sample size is controlled with the `max_samples` parameter if
# `bootstrap=True` (default), otherwise the whole dataset is used to build
# each tree.
#
# Read more in the :ref:`User Guide <forest>`.
#
# Parameters
# ----------
# n_estimators : int, default=100
#     The number of trees in the forest.
#
#     .. versionchanged:: 0.22
#        The default value of ``n_estimators`` changed from 10 to 100
#        in 0.22.
#
# criterion : {"mse", "mae"}, default="mse"
#     The function to measure the quality of a split. Supported criteria
#     are "mse" for the mean squared error, which is equal to variance
#     reduction as feature selection criterion, and "mae" for the mean
#     absolute error.
#
#     .. versionadded:: 0.18
#        Mean Absolute Error (MAE) criterion.
#
# max_depth : int, default=None
#     The maximum depth of the tree. If None, then nodes are expanded until
#     all leaves are pure or until all leaves contain less than
#     min_samples_split samples.
#
# min_samples_split : int or float, default=2
#     The minimum number of samples required to split an internal node:
#
#     - If int, then consider `min_samples_split` as the minimum number.
#     - If float, then `min_samples_split` is a fraction and
#       `ceil(min_samples_split * n_samples)` are the minimum
#       number of samples for each split.
#
#     .. versionchanged:: 0.18
#        Added float values for fractions.
#
# min_samples_leaf : int or float, default=1
#     The minimum number of samples required to be at a leaf node.
#     A split point at any depth will only be considered if it leaves at
#     least ``min_samples_leaf`` training samples in each of the left and
#     right branches.  This may have the effect of smoothing the model,
#     especially in regression.
#
#     - If int, then consider `min_samples_leaf` as the minimum number.
#     - If float, then `min_samples_leaf` is a fraction and
#       `ceil(min_samples_leaf * n_samples)` are the minimum
#       number of samples for each node.
#
#     .. versionchanged:: 0.18
#        Added float values for fractions.
#
# min_weight_fraction_leaf : float, default=0.0
#     The minimum weighted fraction of the sum total of weights (of all
#     the input samples) required to be at a leaf node. Samples have
#     equal weight when sample_weight is not provided.
#
# max_features : {"auto", "sqrt", "log2"}, int or float, default="auto"
#     The number of features to consider when looking for the best split:
#
#     - If int, then consider `max_features` features at each split.
#     - If float, then `max_features` is a fraction and
#       `int(max_features * n_features)` features are considered at each
#       split.
#     - If "auto", then `max_features=n_features`.
#     - If "sqrt", then `max_features=sqrt(n_features)`.
#     - If "log2", then `max_features=log2(n_features)`.
#     - If None, then `max_features=n_features`.
#
#     Note: the search for a split does not stop until at least one
#     valid partition of the node samples is found, even if it requires to
#     effectively inspect more than ``max_features`` features.
#
# max_leaf_nodes : int, default=None
#     Grow trees with ``max_leaf_nodes`` in best-first fashion.
#     Best nodes are defined as relative reduction in impurity.
#     If None then unlimited number of leaf nodes.
#
# min_impurity_decrease : float, default=0.0
#     A node will be split if this split induces a decrease of the impurity
#     greater than or equal to this value.
#
#     The weighted impurity decrease equation is the following::
#
#         N_t / N * (impurity - N_t_R / N_t * right_impurity
#                             - N_t_L / N_t * left_impurity)
#
#     where ``N`` is the total number of samples, ``N_t`` is the number of
#     samples at the current node, ``N_t_L`` is the number of samples in the
#     left child, and ``N_t_R`` is the number of samples in the right child.
#
#     ``N``, ``N_t``, ``N_t_R`` and ``N_t_L`` all refer to the weighted sum,
#     if ``sample_weight`` is passed.
#
#     .. versionadded:: 0.19
#
# min_impurity_split : float, default=None
#     Threshold for early stopping in tree growth. A node will split
#     if its impurity is above the threshold, otherwise it is a leaf.
#
#     .. deprecated:: 0.19
#        ``min_impurity_split`` has been deprecated in favor of
#        ``min_impurity_decrease`` in 0.19. The default value of
#        ``min_impurity_split`` has changed from 1e-7 to 0 in 0.23 and it
#        will be removed in 0.25. Use ``min_impurity_decrease`` instead.
#
# bootstrap : bool, default=True
#     Whether bootstrap samples are used when building trees. If False, the
#     whole dataset is used to build each tree.
#
# oob_score : bool, default=False
#     whether to use out-of-bag samples to estimate
#     the R^2 on unseen data.
#
# n_jobs : int, default=None
#     The number of jobs to run in parallel. :meth:`fit`, :meth:`predict`,
#     :meth:`decision_path` and :meth:`apply` are all parallelized over the
#     trees. ``None`` means 1 unless in a :obj:`joblib.parallel_backend`
#     context. ``-1`` means using all processors. See :term:`Glossary
#     <n_jobs>` for more details.
#
# random_state : int or RandomState, default=None
#     Controls both the randomness of the bootstrapping of the samples used
#     when building trees (if ``bootstrap=True``) and the sampling of the
#     features to consider when looking for the best split at each node
#     (if ``max_features < n_features``).
#     See :term:`Glossary <random_state>` for details.
#
# verbose : int, default=0
#     Controls the verbosity when fitting and predicting.
#
# warm_start : bool, default=False
#     When set to ``True``, reuse the solution of the previous call to fit
#     and add more estimators to the ensemble, otherwise, just fit a whole
#     new forest. See :term:`the Glossary <warm_start>`.
#
# ccp_alpha : non-negative float, default=0.0
#     Complexity parameter used for Minimal Cost-Complexity Pruning. The
#     subtree with the largest cost complexity that is smaller than
#     ``ccp_alpha`` will be chosen. By default, no pruning is performed. See
#     :ref:`minimal_cost_complexity_pruning` for details.
#
#     .. versionadded:: 0.22
#
# max_samples : int or float, default=None
#     If bootstrap is True, the number of samples to draw from X
#     to train each base estimator.
#
#     - If None (default), then draw `X.shape[0]` samples.
#     - If int, then draw `max_samples` samples.
#     - If float, then draw `max_samples * X.shape[0]` samples. Thus,
#       `max_samples` should be in the interval `(0, 1)`.
#
#     .. versionadded:: 0.22
#
# Attributes
# ----------
# base_estimator_ : DecisionTreeRegressor
#     The child estimator template used to create the collection of fitted
#     sub-estimators.
#
# estimators_ : list of DecisionTreeRegressor
#     The collection of fitted sub-estimators.
#
# feature_importances_ : ndarray of shape (n_features,)
#     The impurity-based feature importances.
#     The higher, the more important the feature.
#     The importance of a feature is computed as the (normalized)
#     total reduction of the criterion brought by that feature.  It is also
#     known as the Gini importance.
#
#     Warning: impurity-based feature importances can be misleading for
#     high cardinality features (many unique values). See
#     :func:`sklearn.inspection.permutation_importance` as an alternative.
#
# n_features_ : int
#     The number of features when ``fit`` is performed.
#
# n_outputs_ : int
#     The number of outputs when ``fit`` is performed.
#
# oob_score_ : float
#     Score of the training dataset obtained using an out-of-bag estimate.
#     This attribute exists only when ``oob_score`` is True.
#
# oob_prediction_ : ndarray of shape (n_samples,)
#     Prediction computed with out-of-bag estimate on the training set.
#     This attribute exists only when ``oob_score`` is True.
#
# See Also
# --------
# DecisionTreeRegressor, ExtraTreesRegressor
#
# Notes
# -----
# The default values for the parameters controlling the size of the trees
# (e.g. ``max_depth``, ``min_samples_leaf``, etc.) lead to fully grown and
# unpruned trees which can potentially be very large on some data sets. To
# reduce memory consumption, the complexity and size of the trees should be
# controlled by setting those parameter values.
#
# The features are always randomly permuted at each split. Therefore,
# the best found split may vary, even with the same training data,
# ``max_features=n_features`` and ``bootstrap=False``, if the improvement
# of the criterion is identical for several splits enumerated during the
# search of the best split. To obtain a deterministic behaviour during
# fitting, ``random_state`` has to be fixed.
#
# The default value ``max_features="auto"`` uses ``n_features``
# rather than ``n_features / 3``. The latter was originally suggested in
# [1], whereas the former was more recently justified empirically in [2].
#
# References
# ----------
# .. [1] L. Breiman, "Random Forests", Machine Learning, 45(1), 5-32, 2001.
#
# .. [2] P. Geurts, D. Ernst., and L. Wehenkel, "Extremely randomized
#        trees", Machine Learning, 63(1), 3-42, 2006.
#
# Examples
# --------
# >>> from sklearn.ensemble import RandomForestRegressor
# >>> from sklearn.datasets import make_regression
# >>> X, y = make_regression(n_features=4, n_informative=2,
# ...                        random_state=0, shuffle=False)
# >>> regr = RandomForestRegressor(max_depth=2, random_state=0)
# >>> regr.fit(X, y)
# RandomForestRegressor(...)
# >>> print(regr.predict([[0, 0, 0, 0]]))
# [-8.32987858]
# File:           c:\users\wyatt\appdata\roaming\python\python38\site-packages\sklearn\ensemble\_forest.py
# Type:           ABCMeta
# Subclasses:

# %%
param_grid = {'max_depth': [7, 9, 11, 13],
              'max_features': ["auto", "sqrt", "log2"],
              'n_estimators': [300, 500, 700, 900]
            }

# %%
rf = RandomForestRegressor(random_state=42)
gs = GridSearchCV(rf, param_grid, cv=5, n_jobs=-1)
gs.fit(x_train_4, y_train_4)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [7, 9, 11, 13],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [300, 500, 700, 900]})

# %%
print(gs.best_score_)
print(gs.best_params_)
# Out:
# 0.5393125504409421
# {'max_depth': 11, 'max_features': 'auto', 'n_estimators': 500}

# %%
rf = RandomForestRegressor(random_state=42)
gs = GridSearchCV(rf, param_grid, cv=5, n_jobs=-1)
gs.fit(x_train_1, y_train_1)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [7, 9, 11, 13],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [300, 500, 700, 900]})

# %%
print(gs.best_score_)
print(gs.best_params_)
# Out:
# 0.233204879472125
# {'max_depth': 13, 'max_features': 'auto', 'n_estimators': 500}

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
#sub.to_csv('submission/210608_537316+holiday.csv', index=False)
sub
# Out:
#           num_date_time      answer
# 0       1 2020-08-25 00  8670.35016
# 1       1 2020-08-25 01  8667.75168
# 2       1 2020-08-25 02  8665.35408
# 3       1 2020-08-25 03  8658.63432
# 4       1 2020-08-25 04  8653.11984
# ...                 ...         ...
# 10075  60 2020-08-31 19  4064.82624
# 10076  60 2020-08-31 20  4014.52416
# 10077  60 2020-08-31 21  3839.38272
# 10078  60 2020-08-31 22  3520.99440
# 10079  60 2020-08-31 23  3388.07232
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(16, 8))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()
