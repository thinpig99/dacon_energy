# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
from sklearn.ensemble import RandomForestRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

from sklearn.model_selection import KFold

import datetime
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 베이즈 서치 모델

# %%
PATH = r'C:\Users\Wyatt\wyatt37\data\energy'

# %%
train_col = ['num', 'date_time', 'target', 'temp', 'wind', 'humid', 'rain', 'sunny', 'cooler', 'solar']
test_col = ['num', 'date_time', 'temp', 'wind', 'humid', 'rain', 'sunny', 'cooler', 'solar']

# %%
train = pd.read_csv(PATH + '\\train.csv', encoding='cp949', names=train_col, header=0)
test = pd.read_csv(PATH + '\\test.csv', encoding='cp949', names=test_col, header=0)
sub = pd.read_csv(PATH + '\\sample_submission.csv', encoding='cp949')

# %%
def make_time(train):
    train['date_time'] = pd.to_datetime(train.date_time)
    
    # 1차 time / 지지
    train['month'] = train.date_time.dt.month                    # 월(숫자)
    train['day'] = train.date_time.dt.day                        # 일(숫자)
    train['hour'] = train.date_time.dt.hour                      # 시(숫자)
    train['weekday'] = train.date_time.dt.weekday                # 시(숫자)
    train['dayofyear'] = train.date_time.dt.dayofyear            # 연 기준 몇일째(숫자)
    train['weekofyear'] = train.date_time.dt.isocalendar().week  # 연 기준 몇주째(숫자) (=week)
    
    # 2차 time / 지지
    train['month_start'] = train.date_time.dt.is_month_start
    train['month_end'] = train.date_time.dt.is_month_end
    
    # 여기까지
    
    #train.drop(['date_time', 'datetime'], axis=1, inplace=True)
    
    train.weekofyear = train.weekofyear.astype(int)
    
    return train

# %%
train = make_time(train)
test = make_time(test)

# %%
# cooler와 solar를 넣어주겠습니다.
for i in range(1, 61):
    test.loc[test.num == i, 'cooler'] = train.loc[train.num == i, 'cooler'].mean()
    test.loc[test.num == i, 'solar'] = train.loc[train.num == i, 'solar'].mean()

# %%
test[['temp', 'wind', 'humid', 'rain', 'sunny']] = test[['temp', 'wind', 'humid', 'rain', 'sunny']].interpolate(method='values').round(1)

# %%
# 6월 6일은 현충일
# 8월 15일은 광복절
# 8월 17일은 임시공휴일

# 휴일이 많지 않으니, 주말에 포함시키자.

train.loc[train.weekday >= 5, 'holiday'] = True
train.loc[train.weekday < 5, 'holiday'] = False
train.loc[(train.month == 8) & (train.day == 17), 'holiday'] = True

test.loc[test.weekday >= 5, 'holiday'] = True
test.loc[test.weekday < 5, 'holiday'] = False

train.holiday = train.holiday.astype('bool')
test.holiday = test.holiday.astype('bool')

# %% [markdown]
# ### Bayes Search of RF: 6.50048

# %%
# metric
def SMAPE(true, pred):
    return np.mean((np.abs(true-pred))/(np.abs(true) + np.abs(pred)))*100

# %% [markdown]
# 참고: https://wooono.tistory.com/102

# %% [markdown]
# 학습용 데이터 셋을 먼저 만들어 주고, 테스트용 데이터 셋을 따로 또 만들어 줍니다.

# %%
x_train = train.loc[train.date_time < '2020-08-18', ~train.columns.isin(['target', 'date_time'])]
y_train = train.loc[train.date_time < '2020-08-18'][['num', 'target']]
x_test = train.loc[train.date_time >= '2020-08-18', ~train.columns.isin(['target', 'date_time'])]
y_test = train.loc[train.date_time >= '2020-08-18'][['num', 'target']]

# %%
#목적함수 생성
def rf_cv(n_estimators):
    
    model = RandomForestRegressor(n_estimators = int(round(n_estimators)),
                                  random_state=42,
                                  n_jobs=-1)
    
    # 모델 훈련
    model.fit(x_train_bo, y_train_bo)

    # 예측값 출력
    y_pred= model.predict(x_test_bo)

    # metric 계산
    smape = SMAPE(y_test_bo, y_pred)

    # 오차 최적화로 사용할 metric 반환
    return -smape

# %%
pbounds = {'n_estimators' : (50, 500)}

# %%
# 결과물을 적재할 컨테이너를 만듭니다.
preds = []
fe = []
params = []
models = []
targets = []
oob_scores = []

for i in tqdm(range(1, 61)):
    # 베이즈옵트를 위한 train_test set 을 만듭니다.
    x_train_bo = x_train.loc[x_train.num == i, ~x_train.columns.isin(['num', 'cooler', 'solar'])]
    y_train_bo = y_train.loc[y_train.num == i, 'target']
    x_test_bo = x_test.loc[x_test.num == i, ~x_test.columns.isin(['num', 'cooler', 'solar'])]
    y_test_bo = y_test.loc[y_test.num == i, 'target']
    
    # 예측을 위한 train_test set을 만듭니다.
    x_train_building = train.loc[train.num == i, ~train.columns.isin(['target', 'num', 'cooler', 'solar', 'date_time'])]
    y_train_building = train.loc[train.num == i, 'target']
    x_test_building = test.loc[test.num == i, ~test.columns.isin(['num', 'cooler', 'solar', 'date_time'])]
    
    # 베이즈 옵트를 통해 최적화된 하이퍼 파라미터를 추출합니다.
    bo = BayesianOptimization(f = rf_cv, pbounds = pbounds, verbose = 0, random_state = 0 )
    bo.maximize(init_points=10, n_iter = 20, acq='ei', xi=0.01)
    best_params = bo.max['params']
    best_target = abs(bo.max['target'])
    
    # 하이퍼 파라미터가 소수점으로 되어 있으므로, rounding을 해줍니다.
    for k, v in best_params.items():
        best_params[k] = round(v)
    
    # 최적화된 하이퍼 파라미터로 모델을 생성하고 학습합니다.
    model = RandomForestRegressor(**best_params, oob_score=True ,random_state=42)
    model.fit(x_train_building, y_train_building)
    pred = model.predict(x_test_building)
    
    # 결과물을 적재해줍니다.
    models.append(model)
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    params.append(best_params)
    targets.append(best_target)
    oob_scores.append(model.oob_score_)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [16:14<00:00, 16.25s/it]

# %%
score_df = pd.DataFrame(targets, index=list(range(1, 61)), columns=['score'])
plt.figure(figsize=(22, 4))
plots = sns.barplot(data=score_df, x=score_df.index, y='score')

for bar in plots.patches:
    height = bar.get_height()
    plt.text(bar.get_x()+ 0.25 * bar.get_width(), bar.get_height(),
             '{:.2f}'.format(height),
             ha='center', va='center')
plt.show()

# %%
np.sum(oob_scores)
# Out:
# 57.155972352232816

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub.to_csv('submission/210611_bo3-rf.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8675.225705
# 1       1 2020-08-25 01  8672.042361
# 2       1 2020-08-25 02  8668.667803
# 3       1 2020-08-25 03  8663.823738
# 4       1 2020-08-25 04  8655.576787
# ...                 ...          ...
# 10075  60 2020-08-31 19  4063.386240
# 10076  60 2020-08-31 20  4014.581760
# 10077  60 2020-08-31 21  3796.577280
# 10078  60 2020-08-31 22  3522.746880
# 10079  60 2020-08-31 23  3376.650240
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=x_train_building.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 6))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.02+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## 일반 모델

# %%
train = pd.read_csv(PATH + '\\train.csv', encoding='cp949', names=train_col, header=0)
test = pd.read_csv(PATH + '\\test.csv', encoding='cp949', names=test_col, header=0)
sub = pd.read_csv(PATH + '\\sample_submission.csv', encoding='cp949')

# %%
def make_time(train):
    train['datetime'] = pd.to_datetime(train.date_time)
    
    # 1차 time / 지지
    train['month'] = train.datetime.dt.month                    # 월(숫자)
    train['day'] = train.datetime.dt.day                        # 일(숫자)
    train['hour'] = train.datetime.dt.hour                      # 시(숫자)
    train['weekday'] = train.datetime.dt.weekday                # 시(숫자)
    train['dayofyear'] = train.datetime.dt.dayofyear            # 연 기준 몇일째(숫자)
    train['weekofyear'] = train.datetime.dt.isocalendar().week  # 연 기준 몇주째(숫자) (=week)
    
    # 2차 time / 지지
    train['month_start'] = train.datetime.dt.is_month_start
    train['month_end'] = train.datetime.dt.is_month_end
    
    # 여기까지
    
    train.drop(['date_time', 'datetime'], axis=1, inplace=True)
    
    train.weekofyear = train.weekofyear.astype(int)
    
    return train

# %%
train = make_time(train)
test = make_time(test)

# %%
# cooler와 solar를 넣어주겠습니다.
for i in range(1, 61):
    test.loc[test.num == i, 'cooler'] = train.loc[train.num == i, 'cooler'].mean()
    test.loc[test.num == i, 'solar'] = train.loc[train.num == i, 'solar'].mean()

# %%
test[['temp', 'wind', 'humid', 'rain', 'sunny']] = test[['temp', 'wind', 'humid', 'rain', 'sunny']].interpolate(method='values').round(1)

# %%
# 6월 6일은 현충일
# 8월 15일은 광복절
# 8월 17일은 임시공휴일

# 휴일이 많지 않으니, 주말에 포함시키자.

train.loc[train.weekday >= 5, 'holiday'] = True
train.loc[train.weekday < 5, 'holiday'] = False
train.loc[(train.month == 8) & (train.day == 17), 'holiday'] = True

test.loc[test.weekday >= 5, 'holiday'] = True
test.loc[test.weekday < 5, 'holiday'] = False

train.holiday = train.holiday.astype('bool')
test.holiday = test.holiday.astype('bool')

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_building_{}'.format(i)] = train.loc[train.num == i,
                                                         ~train.columns.isin(['target', 'num', 'cooler', 'solar'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_building_{}_y'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_building_{}'.format(i)] = test.loc[test.num == i,
                                                       ~test.columns.isin(['num', 'cooler', 'solar'])]

# %%
train_building_60.shape, train_building_60_y.shape, test_building_60.shape
# Out:
# ((2040, 14), (2040,), (168, 14))

# %% [markdown]
# ### RF: 6.50285

# %%
preds = []
fe = []
oob_scores = []
for i in tqdm(range(1, 61)):
    rf = RandomForestRegressor(random_state=42, oob_score=True)
    rf.fit(globals()['train_building_{}'.format(i)], globals()['train_building_{}_y'.format(i)])
    pred = rf.predict(globals()['test_building_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(rf.feature_importances_)
    oob_scores.append(rf.oob_score_)
    
np.sum(oob_scores)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:39<00:00,  1.52it/s]
# 57.189455797322154

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
#sub.to_csv('submission/210608_537316+holiday.csv', index=False)
sub
# Out:
#           num_date_time      answer
# 0       1 2020-08-25 00  8670.35016
# 1       1 2020-08-25 01  8667.75168
# 2       1 2020-08-25 02  8665.35408
# 3       1 2020-08-25 03  8658.63432
# 4       1 2020-08-25 04  8653.11984
# ...                 ...         ...
# 10075  60 2020-08-31 19  4064.82624
# 10076  60 2020-08-31 20  4014.52416
# 10077  60 2020-08-31 21  3839.38272
# 10078  60 2020-08-31 22  3520.99440
# 10079  60 2020-08-31 23  3388.07232
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_building_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(16, 8))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# #### RF_noWeekofyear

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_building_{}'.format(i)] = train.loc[train.num == i,
                                                         ~train.columns.isin(['target', 'num',
                                                                              'cooler', 'solar',
                                                                              'weekofyear'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_building_{}_y'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_building_{}'.format(i)] = test.loc[test.num == i,
                                                       ~test.columns.isin(['num', 'cooler', 'solar', 'weekofyear'])]

# %%
train_building_60.shape, train_building_60_y.shape, test_building_60.shape
# Out:
# ((2040, 13), (2040,), (168, 13))

# %%
preds = []
fe = []
oob_scores = []
for i in tqdm(range(1, 61)):
    rf = RandomForestRegressor(random_state=42, oob_score=True)
    rf.fit(globals()['train_building_{}'.format(i)], globals()['train_building_{}_y'.format(i)])
    pred = rf.predict(globals()['test_building_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(rf.feature_importances_)
    oob_scores.append(rf.oob_score_)
    
np.sum(oob_scores)
# Out:
#  20%|███████████████▏                                                            | 12/60 [00:07<00:30,  1.57it/s]

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub.to_csv('submission/210614_rf-nowoy.csv', index=False)
sub

# %%
plt.figure(figsize=(8, 4))
sns.barplot(data=fe_avg)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Extra Trees: 7.42293

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
preds = []
fe = []
scores = []
for i in tqdm(range(1, 61)):
    et = ExtraTreesRegressor(random_state=42)
    et.fit(globals()['train_building_{}'.format(i)], globals()['train_building_{}_y'.format(i)])
    pred = et.predict(globals()['test_building_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(et.feature_importances_)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:26<00:00,  2.22it/s]

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub.to_csv('submission/210610_537757-with-extratrees.csv', index=False)
sub
# Out:
#           num_date_time      answer
# 0       1 2020-08-25 00  8677.97712
# 1       1 2020-08-25 01  8674.68528
# 2       1 2020-08-25 02  8669.57256
# 3       1 2020-08-25 03  8658.96480
# 4       1 2020-08-25 04  8637.66504
# ...                 ...         ...
# 10075  60 2020-08-31 19  4174.01424
# 10076  60 2020-08-31 20  4017.57840
# 10077  60 2020-08-31 21  3777.42960
# 10078  60 2020-08-31 22  3608.02512
# 10079  60 2020-08-31 23  3556.09008
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_building_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# 기각

# %% [markdown]
# ### XGB: 6.40181

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_x_{}'.format(i)] = train.loc[train.num == i, ~train.columns.isin(['target', 'num', 'cooler', 'solar'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_y_{}'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_x_{}'.format(i)] = test.loc[test.num == i, ~test.columns.isin(['num', 'cooler', 'solar'])]

# %%
preds = []
fe = []
for i in range(1, 61):
    print(i, '번째 모델---------------------------------------------------------------------')    
    cross = KFold(n_splits=5, shuffle=True, random_state=42)
    folds = []
    for train_idx, valid_idx in cross.split(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)]):
        folds.append((train_idx, valid_idx))
        
    models={}
    for fold in range(5):
        train_idx, valid_idx = folds[fold]
        X_tra = globals()['train_x_{}'.format(i)].iloc[train_idx, :]
        y_tra = globals()['train_y_{}'.format(i)].iloc[train_idx]
        X_val = globals()['train_x_{}'.format(i)].iloc[valid_idx, :]
        y_val = globals()['train_y_{}'.format(i)].iloc[valid_idx]

        model=XGBRegressor(learning_rate=0.027, random_state=42, n_estimators=1000)
        model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
                  eval_metric='rmse',
                  early_stopping_rounds=30, verbose=1000)
        models[fold]=model
    
    pred = models[0].predict(globals()['test_x_{}'.format(i)]) / 5
    for k in range(1, 5):
        pred += models[k].predict(globals()['test_x_{}'.format(i)]) / 5
    
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
# Out:
# 1 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:8313.51367	validation_1-rmse:8312.31055
# [613]	validation_0-rmse:9.82404	validation_1-rmse:24.95472
# [0]	validation_0-rmse:8313.42188	validation_1-rmse:8312.69727
# [999]	validation_0-rmse:5.88348	validation_1-rmse:21.46989
# [0]	validation_0-rmse:8313.57519	validation_1-rmse:8312.05762
# [554]	validation_0-rmse:10.11942	validation_1-rmse:42.12930
# [0]	validation_0-rmse:8314.43262	validation_1-rmse:8308.50586
# [432]	validation_0-rmse:11.91304	validation_1-rmse:32.84063
# [0]	validation_0-rmse:8311.45606	validation_1-rmse:8320.82422
# [526]	validation_0-rmse:10.74503	validation_1-rmse:23.19531
# 2 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:
번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:5856.41309	validation_1-rmse:5796.11230
# [424]	validation_0-rmse:137.38655	validation_1-rmse:349.20041
# [0]	validation_0-rmse:5872.88916	validation_1-rmse:5727.01221
# [391]	validation_0-rmse:159.13704	validation_1-rmse:308.69452
# [0]	validation_0-rmse:5843.98975	validation_1-rmse:5848.20361
# [957]	validation_0-rmse:82.18605	validation_1-rmse:325.14337
# [0]	validation_0-rmse:5833.78760	validation_1-rmse:5884.60107
# [264]	validation_0-rmse:183.21933	validation_1-rmse:345.06082
# [0]	validation_0-rmse:5814.83496	validation_1-rmse:5961.13477
# [281]	validation_0-rmse:180.60373	validation_1-rmse:328.82873
# 31 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:5806.49756	validation_1-rmse:5811.95264
# [319]	validation_0-rmse:23.55584	validation_1-rmse:118.94237
# [0]	validation_0-rmse:5809.55273	validation_1-rmse:5799.28809
# [336]	validation_0-rmse:20.60269	validation_1-rmse:74.61301
# [0]	validation_0-rmse:5808.59961	validation_1-rmse:5802.98975
# [286]	validation_0-rmse:24.12788	validation_1-rmse:78.46549
# [0]	validation_0-rmse:5807.07910	validation_1-rmse:5809.34912
# [595]	validation_0-rmse:12.84107	validation_1-rmse:197.14967
# [0]	validation_0-rmse:5805.94580	validation_1-rmse:5814.08740
# [924]	validation_0-rmse:8.44706	validation_1-rmse:31.05690
# 32 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:2337.47192	validation_1-rmse:2337.23853
# [769]	validation_0-rmse:3.38071	validation_1-rmse:8.42025
# [0]	validation_0-rmse:2338.14722	validation_1-rmse:2334.44360
# [558]	validation_0-rmse:4.72918	validation_1-rmse:9.25135
# [0]	validation_0-rmse:2337.50562	validation_1-rmse:2337.10132
# [614]	validation_0-rmse:4.18841	validation_1-rmse:9.83134
# [0]	validation_0-rmse:2336.38647	validation_1-rmse:2341.72803
# [516]	validation_0-rmse:4.60884	validation_1-rmse:9.77897
# [0]	validation_0-rmse:2337.62231	validation_1-rmse:2336.61670
# [705]	validation_0-rmse:3.71507	validation_1-rmse:9.03296
# 33 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:2509.14185	validation_1-rmse:2511.24341
# [267]	validation_0-rmse:14.44608	validation_1-rmse:25.93098
# [0]	validation_0-rmse:2511.14795	validation_1-rmse:2502.93945
# [788]	validation_0-rmse:5.38393	validation_1-rmse:21.99580
# [0]	validation_0-rmse:2509.65869	validation_1-rmse:2509.11060
# [238]	validation_0-rmse:17.77962	validation_1-rmse:55.72249
# [0]	validation_0-rmse:2507.72632	validation_1-rmse:2517.04419
# [271]	validation_0-rmse:11.82529	validation_1-rmse:92.80048
# [0]	validation_0-rmse:2510.07422	validation_1-rmse:2507.39111
# [226]	validation_0-rmse:18.98163	validation_1-rmse:36.26450
# 34 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:949.27789	validation_1-rmse:947.59430
# [669]	validation_0-rmse:21.49472	validation_1-rmse:114.16154
# [0]	validation_0-rmse:955.07812	validation_1-rmse:923.08160
# [173]	validation_0-rmse:64.07208	validation_1-rmse:118.05843
# [0]	validation_0-rmse:946.70557	validation_1-rmse:956.78101
# [358]	validation_0-rmse:30.05376	validation_1-rmse:127.67534
# [0]	validation_0-rmse:952.05890	validation_1-rmse:935.50262
# [811]	validation_0-rmse:18.37968	validation_1-rmse:109.31416
# [0]	validation_0-rmse:940.94861	validation_1-rmse:980.53040
# [607]	validation_0-rmse:24.09013	validation_1-rmse:92.50479
# 35 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:
번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:920.14062	validation_1-rmse:908.64227
# [604]	validation_0-rmse:12.00206	validation_1-rmse:27.78989
# [0]	validation_0-rmse:922.82764	validation_1-rmse:897.70581
# [999]	validation_0-rmse:7.76072	validation_1-rmse:31.28085
# [0]	validation_0-rmse:917.89648	validation_1-rmse:917.68829
# [999]	validation_0-rmse:8.29163	validation_1-rmse:28.37125
# [0]	validation_0-rmse:911.44605	validation_1-rmse:943.25421
# [539]	validation_0-rmse:12.61899	validation_1-rmse:28.23861
# [0]	validation_0-rmse:917.03467	validation_1-rmse:921.34375
# [967]	validation_0-rmse:8.41784	validation_1-rmse:28.98070
# 59 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:1083.21851	validation_1-rmse:1060.54651
# [169]	validation_0-rmse:104.90974	validation_1-rmse:154.14159
# [0]	validation_0-rmse:1082.40173	validation_1-rmse:1064.48352
# [212]	validation_0-rmse:99.20558	validation_1-rmse:158.42381
# [0]	validation_0-rmse:1075.39990	validation_1-rmse:1092.75952
# [214]	validation_0-rmse:100.69334	validation_1-rmse:158.77718
# [0]	validation_0-rmse:1076.83154	validation_1-rmse:1086.47095
# [201]	validation_0-rmse:101.22839	validation_1-rmse:160.25815
# [0]	validation_0-rmse:1075.99036	validation_1-rmse:1089.74841
# [190]	validation_0-rmse:103.87165	validation_1-rmse:151.15033
# 60 번째 모델---------------------------------------------------------------------
# [0]	validation_0-rmse:3294.08081	validation_1-rmse:3268.23242
# [706]	validation_0-rmse:39.20495	validation_1-rmse:116.10313
# [0]	validation_0-rmse:3294.88403	validation_1-rmse:3265.25024
# [725]	validation_0-rmse:38.21418	validation_1-rmse:123.16505
# [0]	validation_0-rmse:3289.60547	validation_1-rmse:3287.02197
# [469]	validation_0-rmse:52.51111	validation_1-rmse:130.39537
# [0]	validation_0-rmse:3284.01465	validation_1-rmse:3308.84204
# [467]	validation_0-rmse:54.12527	validation_1-rmse:117.72057
# [0]	validation_0-rmse:3282.44385	validation_1-rmse:3315.38013
# [458]	validation_0-rmse:52.63892	validation_1-rmse:126.93353

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub.to_csv('submission/210612_537757-with-xgb.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8679.375000
# 1       1 2020-08-25 01  8656.330078
# 2       1 2020-08-25 02  8642.869141
# 3       1 2020-08-25 03  8633.066406
# 4       1 2020-08-25 04  8623.132812
# ...                 ...          ...
# 10075  60 2020-08-31 19  4059.909668
# 10076  60 2020-08-31 20  3951.680664
# 10077  60 2020-08-31 21  3808.103271
# 10078  60 2020-08-31 22  3685.906982
# 10079  60 2020-08-31 23  3443.524414
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_building_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ### LGBM: 6.34797

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_x_{}'.format(i)] = train.loc[train.num == i, ~train.columns.isin(['target', 'num', 'cooler', 'solar'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_y_{}'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_x_{}'.format(i)] = test.loc[test.num == i, ~test.columns.isin(['num', 'cooler', 'solar'])]

# %%
preds = []
fes = []

for i in range(1, 61):
    print(i, '번째 모델---------------------------------------------------------------------')    
    cross = KFold(n_splits=5, shuffle=True, random_state=42)
    folds = []
    for train_idx, valid_idx in cross.split(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)]):
        folds.append((train_idx, valid_idx))
        
    models={}
    for fold in range(5):
        train_idx, valid_idx = folds[fold]
        X_tra = globals()['train_x_{}'.format(i)].iloc[train_idx, :]
        y_tra = globals()['train_y_{}'.format(i)].iloc[train_idx]
        X_val = globals()['train_x_{}'.format(i)].iloc[valid_idx, :]
        y_val = globals()['train_y_{}'.format(i)].iloc[valid_idx]

        model=LGBMRegressor(learning_rate=0.027, random_state=42, n_estimators=10000)
        model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
                  eval_metric='smape',
                  early_stopping_rounds=20, verbose=10000)
        models[fold]=model
    
    pred = models[0].predict(globals()['test_x_{}'.format(i)]) / 5
    fe = models[0].feature_importances_ / 5
    for k in range(1, 5):
        pred += models[k].predict(globals()['test_x_{}'.format(i)]) / 5
        fe += models[k].feature_importances_ / 5
    
    preds.append(pred.tolist())
    fes.append(fe)
# Out:
# 1 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [616]	training's l2: 267.26	valid_1's l2: 530.674
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [621]	training's l2: 255.778	valid_1's l2: 509.147
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [734]	training's l2: 85.2974	valid_1's l2: 1737.04
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [386]	training's l2: 347.507	valid_1's l2: 745.445
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [545]	training's l2: 274.845	valid_1's l2: 563.222
# 2 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [335]	training's l2: 393.395	valid_1's l2: 1044.14
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [410]	training's l2: 289.183	valid_1's l2: 1235.66
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [347]	training's l2: 352.735	valid_1's l2: 1305.52
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [392]	training's l2: 306.877	valid_1's l2: 1145.17
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [610]	training's l2: 198.432	valid_1's l2: 1097.88
# 3 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [568]	training's l2: 573.901	valid_1's l2: 4416.75
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [305]	training's l2: 1121.92	valid_1's l2: 2374.31
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [436]	training's l2: 797.454	valid_1's l2: 3965.05
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [350]	training's l2: 893.26	valid_1's l2: 4106.2
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [376]	training's l2: 908.409	valid_1's l2: 2839.32
# 4 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [379]	training's l2: 4196.31	valid_1's l2: 15380.3
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [425]	training's l2: 4118.24	valid_1's l2: 13196.7
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [568]	training's l2: 2932.98	valid_1's l2: 12917.8
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [299]	training's l2: 5152.39	valid_1's l2: 20048.1
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [571]	training's l2: 2840.78	valid_1's l2: 16395.7
# 5 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [997]	training's l2: 1852.34	valid_1's l2: 16288.2
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1415]	training's l2: 1033.78	valid_1's l2: 14153
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1001]	training's l2: 1695.66	valid_1's l2: 17470
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [660]	training's l2: 3154.11	valid_1's l2: 17166.1
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [821]	training's l2: 2459.76	valid_1's l2: 16366.4
# 6 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [680]	training's l2: 225.229	valid_1's l2: 1643.31
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [461]	training's l2: 374.391	valid_1's l2: 1592.29
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [706]	training's l2: 229.974	valid_1's l2: 2104.01
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [647]	training's l2: 245.479	valid_1's l2: 1667.91
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [372]	training's l2: 435.972	valid_1's l2: 2808.57
# 7 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [496]	training's l2: 1683.97	valid_1's l2: 7538.26
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
#
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [723]	training's l2: 142.814	valid_1's l2: 878.564
# 59 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [95]	training's l2: 17155.1	valid_1's l2: 23240.3
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [161]	training's l2: 14001.5	valid_1's l2: 24136.4
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [123]	training's l2: 15099.5	valid_1's l2: 25956
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [162]	training's l2: 13784.5	valid_1's l2: 24766.8
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [144]	training's l2: 14839	valid_1's l2: 22358.3
# 60 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [322]	training's l2: 5526.59	valid_1's l2: 12741.5
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [252]	training's l2: 6342.01	valid_1's l2: 15154.4
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [377]	training's l2: 4639.43	valid_1's l2: 17883.2
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [391]	training's l2: 4707.34	valid_1's l2: 13410.5
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [319]	training's l2: 5237.06	valid_1's l2: 16565.6

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub.to_csv('submission/210612_537757-with-lgbm.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8679.823112
# 1       1 2020-08-25 01  8666.608097
# 2       1 2020-08-25 02  8653.262284
# 3       1 2020-08-25 03  8640.817195
# 4       1 2020-08-25 04  8634.318897
# ...                 ...          ...
# 10075  60 2020-08-31 19  4036.639616
# 10076  60 2020-08-31 20  3930.032691
# 10077  60 2020-08-31 21  3796.872690
# 10078  60 2020-08-31 22  3613.909907
# 10079  60 2020-08-31 23  3338.709352
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fes, axis=0),
                      index=train_building_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# #### 538870+catfeatures: 6.56811

# %%
train_x_1.head()
# Out:
#    temp  wind  humid  rain  sunny  month  day  hour  weekday  dayofyear  \
# 0  17.6   2.5   92.0   0.8    0.0      6    1     0        0        153
# 1  17.7   2.9   91.0   0.3    0.0      6    1     1        0        153
# 2  17.5   3.2   91.0   0.0    0.0      6    1     2        0        153
# 3  17.1   3.2   91.0   0.0    0.0      6    1     3        0        153
# 4  17.0   3.3   92.0   0.0    0.0      6    1     4        0        153
#
#    weekofyear  month_start  month_end  holiday
# 0          23         True      False    False
# 1          23         True      False    False
# 2          23         True      False    False
# 3          23         True      False    False
# 4          23         True      False    False

# %%
cat_features = [5, 7, 8, 11, 12, 13]

# %%
preds = []
fes = []

for i in range(1, 61):
    print(i, '번째 모델---------------------------------------------------------------------')    
    cross = KFold(n_splits=5, shuffle=True, random_state=42)
    folds = []
    for train_idx, valid_idx in cross.split(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)]):
        folds.append((train_idx, valid_idx))
        
    models={}
    for fold in range(5):
        train_idx, valid_idx = folds[fold]
        X_tra = globals()['train_x_{}'.format(i)].iloc[train_idx, :]
        y_tra = globals()['train_y_{}'.format(i)].iloc[train_idx]
        X_val = globals()['train_x_{}'.format(i)].iloc[valid_idx, :]
        y_val = globals()['train_y_{}'.format(i)].iloc[valid_idx]

        model=LGBMRegressor(learning_rate=0.027, random_state=42, n_estimators=10000)
        model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
                  eval_metric='smape', categorical_feature=cat_features,
                  early_stopping_rounds=20, verbose=10000)
        models[fold]=model
    
    pred = models[0].predict(globals()['test_x_{}'.format(i)]) / 5
    fe = models[0].feature_importances_ / 5
    for k in range(1, 5):
        pred += models[k].predict(globals()['test_x_{}'.format(i)]) / 5
        fe += models[k].feature_importances_ / 5
    
    preds.append(pred.tolist())
    fes.append(fe)
# Out:
# 1 번째 모델---------------------------------------------------------------------
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
#
# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fes, axis=0),
                      index=train_building_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ### CATB: 6.96521(noCatFeatures)

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_x_{}'.format(i)] = train.loc[train.num == i, ~train.columns.isin(['target', 'num', 'cooler', 'solar'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_y_{}'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_x_{}'.format(i)] = test.loc[test.num == i, ~test.columns.isin(['num', 'cooler', 'solar'])]

# %%
train_x_1.head(3)
# Out:
#    temp  wind  humid  rain  sunny  month  day  hour  weekday  dayofyear  \
# 0  17.6   2.5   92.0   0.8    0.0      6    1     0        0        153
# 1  17.7   2.9   91.0   0.3    0.0      6    1     1        0        153
# 2  17.5   3.2   91.0   0.0    0.0      6    1     2        0        153
#
#    weekofyear  month_start  month_end  holiday
# 0          23         True      False    False
# 1          23         True      False    False
# 2          23         True      False    False

# %% [markdown]
# #### cat_features = [5, 7, 8, 11, 12, 13]: 7.25982

# %%
cat_features = [5, 7, 8, 11, 12, 13]

# %%
now = datetime.datetime.now()
print(now)

preds = []
fe = []
for i in range(1, 61):
    print(i, '번째 모델---------------------------------------------------------------------')    
    cross = KFold(n_splits=5, shuffle=True, random_state=42)
    folds = []
    for train_idx, valid_idx in cross.split(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)]):
        folds.append((train_idx, valid_idx))
        
    models={}
    for fold in range(5):
        train_idx, valid_idx = folds[fold]
        X_tra = globals()['train_x_{}'.format(i)].iloc[train_idx, :]
        y_tra = globals()['train_y_{}'.format(i)].iloc[train_idx]
        X_val = globals()['train_x_{}'.format(i)].iloc[valid_idx, :]
        y_val = globals()['train_y_{}'.format(i)].iloc[valid_idx]

        model = CatBoostRegressor(learning_rate=0.027, random_state=42, n_estimators=10000, eval_metric='SMAPE')
        model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
                  cat_features=cat_features,
                  early_stopping_rounds=20, verbose=10000)
        models[fold] = model
    
    pred = models[0].predict(globals()['test_x_{}'.format(i)]) / 5
    for k in range(1, 5):
        pred += models[k].predict(globals()['test_x_{}'.format(i)]) / 5
    
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    
now = datetime.datetime.now()
print(now)
# Out:
# 2021-06-12 01:57:36.679950
# 1 번째 모델---------------------------------------------------------------------
# 0:	learn: 127.6721071	test: 127.6721071	test1: 129.0152224	best: 129.0152224 (0)	total: 49.3ms	remaining: 8m 13s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 23.78823678
# bestIteration = 2279
#
# Shrink model to first 2280 iterations.
# 0:	learn: 130.2973389	test: 130.2973389	test1: 118.0028987	best: 118.0028987 (0)	total: 24.8ms	remaining: 4m 7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 26.4776705
# bestIteration = 1559
#
# Shrink model to first 1560 iterations.
# 0:	learn: 125.8814936	test: 125.8814936	test1: 135.7292478	best: 135.7292478 (0)	total: 56.9ms	remaining: 9m 28s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 44.20149541
# bestIteration = 1135
#
# Shrink model to first 1136 iterations.
# 0:	learn: 127.2192292	test: 127.2192292	test1: 130.6258744	best: 130.6258744 (0)	total: 34.8ms	remaining: 5m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 31.23062896
# bestIteration = 803
#
# Shrink model to first 804 iterations.
# 0:	learn: 128.5041132	test: 128.5041132	test1: 125.7846249	best: 125.7846249 (0)	total: 45.6ms	remaining: 7m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 25.2697879
# bestIteration = 1632
#
# Shrink model to first 1633 iterations.
# 2 번째 모델---------------------------------------------------------------------
# 0:	learn: 326.2955681	test: 326.1838760	test1: 341.0502201	best: 341.0502201 (0)	total: 44.4ms	remaining: 7m 24s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 40.26361869
# bestIteration = 1225
#
# Shrink model to first 1226 iterations.
# 0:	learn: 330.9265108	test: 330.5714769	test1: 320.9515630	best: 320.9515630 (0)	total: 24.2ms	remaining: 4m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 38.49725145
# bestIteration = 1355
#
# Shrink model to first 1356 iterations.
# 0:	learn: 330.6218794	test: 330.1233582	test1: 322.7967844	best: 322.7967844 (0)	total: 90.6ms	remaining: 15m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 42.04951513
# bestIteration = 1040
#
# Shrink model to first 1041 iterations.
# 0:	learn: 328.1199971	test: 327.8518269	test1: 332.3208520	best: 332.3208520 (0)	total: 45.2ms	remaining: 7m 31s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 46.3311399
# bestIteration = 1318
#
# Shrink model to first 1319 iterations.
# 3 번째 모델---------------------------------------------------------------------
# 0:	learn: 172.3790026	test: 172.3584276	test1: 184.6358530	best: 184.6358530 (0)	total: 26.9ms	remaining: 4m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 81.34286039
# bestIteration = 1622
#
# Shrink model to first 1623 iterations.
# 0:	learn: 176.8517733	test: 176.8517733	test1: 166.2612275	best: 166.2612275 (0)	total: 59.3ms	remaining: 9m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 58.64278057
# bestIteration = 938
#
# Shrink model to first 939 iterations.
# 0:	learn: 174.0353012	test: 174.0274859	test1: 178.7158224	best: 178.7158224 (0)	total: 24.4ms	remaining: 4m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 85.30493607
# bestIteration = 2175
#
# Shrink model to first 2176 iterations.
# 0:	learn: 174.0121802	test: 174.0121802	test1: 178.4891921	best: 178.4891921 (0)	total: 56.1ms	remaining: 9m 20s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 80.03753792
# bestIteration = 1113
#
# Shrink model to first 1114 iterations.
# 0:	learn: 176.7573111	test: 176.7536059	test1: 167.6848443	best: 167.6848443 (0)	total: 45.2ms	remaining: 7m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 70.35967487
# bestIteration = 483
#
# Shrink model to first 484 iterations.
# 4 번째 모델---------------------------------------------------------------------
# 0:	learn: 489.3478495	test: 489.2139704	test1: 521.3649069	best: 521.3649069 (0)	total: 64.6ms	remaining: 10m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 154.9415612
# bestIteration = 1027
#
# Shrink model to first 1028 iterations.
# 0:	learn: 497.0621909	test: 496.7489450	test1: 489.3104306	best: 489.3104306 (0)	total: 24.1ms	remaining: 4m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 129.4514908
# bestIteration = 1361
#
# Shrink model to first 1362 iterations.
# 0:	learn: 501.9348323	test: 501.3558991	test1: 470.1804175	best: 470.1804175 (0)	total: 19.5ms	remaining: 3m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 132.3688
# bestIteration = 921
#
# Shrink model to first 922 iterations.
# 0:	learn: 496.5978264	test: 496.4485296	test1: 490.8264242	best: 490.8264242 (0)	total: 24.4ms	remaining: 4m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 168.5949283
# bestIteration = 1134
#
# Shrink model to first 1135 iterations.
# 0:	learn: 493.1655491	test: 493.0955617	test1: 505.5829310	best: 505.5829310 (0)	total: 48ms	remaining: 8m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 148.2641993
# bestIteration = 1028
#
# Shrink model to first 1029 iterations.
# 5 번째 모델---------------------------------------------------------------------
# 0:	learn: 400.6161721	test: 400.3963125	test1: 406.7918111	best: 406.7918111 (0)	total: 43.7ms	remaining: 7m 17s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 154.1614231
# bestIteration = 1611
#
# Shrink model to first 1612 iterations.
# 0:	learn: 400.0797478	test: 399.8045098	test1: 407.2856572	best: 407.2856572 (0)	total: 37.3ms	remaining: 6m 12s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 153.9856271
# bestIteration = 1566
#
# Shrink model to first 1567 iterations.
# 0:	learn: 408.9058513	test: 408.4839261	test1: 369.3913139	best: 369.3913139 (0)	total: 35.1ms	remaining: 5m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 156.5368448
# bestIteration = 1628
#
# Shrink model to first 1629 iterations.
# 0:	learn: 402.3724039	test: 402.0257586	test1: 396.7053155	best: 396.7053155 (0)	total: 49.1ms	remaining: 8m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 144.4899005
# bestIteration = 2559
#
# Shrink model to first 2560 iterations.
# 0:	learn: 395.2690156	test: 395.1972620	test1: 425.0283599	best: 425.0283599 (0)	total: 41.7ms	remaining: 6m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 152.6564232
# bestIteration = 1853
#
# Shrink model to first 1854 iterations.
# 6 번째 모델---------------------------------------------------------------------
# 0:	learn: 715.1869847	test: 714.8558430	test1: 744.5173987	best: 744.5173987 (0)	total: 41.8ms	remaining: 6m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 56.29552976
# bestIteration = 2254
#
# Shrink model to first 2255 iterations.
# 0:	learn: 724.7105494	test: 724.6116441	test1: 708.6833003	best: 708.6833003 (0)	total: 66.6ms	remaining: 11m 6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 67.09839119
# bestIteration = 996
#
# Shrink model to first 997 iterations.
# 0:	learn: 721.6483646	test: 720.9849648	test1: 716.0412469	best: 716.0412469 (0)	total: 41.7ms	remaining: 6m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 52.62674155
# bestIteration = 3111
#
# Shrink model to first 3112 iterations.
# 0:	learn: 716.9889651	test: 716.2716173	test1: 733.1154105	best: 733.1154105 (0)	total: 49.4ms	remaining: 8m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 57.55126327
# bestIteration = 2674
#
# Shrink model to first 2675 iterations.
# 0:	learn: 725.4687737	test: 724.9702331	test1: 700.5553522	best: 700.5553522 (0)	total: 49.3ms	remaining: 8m 13s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 71.3859633
# bestIteration = 1922
#
# Shrink model to first 1923 iterations.
# 7 번째 모델---------------------------------------------------------------------
# 0:	learn: 591.3776381	test: 591.1253353	test1: 600.8263515	best: 600.8263515 (0)	total: 16.7ms	remaining: 2m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 101.3032459
# bestIteration = 2305
#
# Shrink model to first 2306 iterations.
# 0:	learn: 596.8650132	test: 596.2024602	test1: 577.5774537	best: 577.5774537 (0)	total: 27.1ms	remaining: 4m 31s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 99.02044118
# bestIteration = 2024
#
# Shrink model to first 2025 iterations.
# 0:	learn: 592.2610088	test: 591.9212057	test1: 598.3825061	best: 598.3825061 (0)	total: 23.4ms	remaining: 3m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 112.8929262
# bestIteration = 2030
#
# Shrink model to first 2031 iterations.
# 0:	learn: 590.0308290	test: 589.6812196	test1: 607.2845098	best: 607.2845098 (0)	total: 24.6ms	remaining: 4m 6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 99.63847975
# bestIteration = 2160
#
# Shrink model to first 2161 iterations.
# 0:	learn: 595.8216865	test: 595.8773684	test1: 581.9534127	best: 581.9534127 (0)	total: 33.9ms	remaining: 5m 39s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 109.6384129
# bestIteration = 1432
#
# Shrink model to first 1433 iterations.
# 8 번째 모델---------------------------------------------------------------------
# 0:	learn: 3914.8171443	test: 3913.1520389	test1: 4007.8564556	best: 4007.8564556 (0)	total: 41.6ms	remaining: 6m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 509.4541507
# bestIteration = 2279
#
# Shrink model to first 2280 iterations.
# 0:	learn: 3962.6390064	test: 3961.0092756	test1: 3832.1813064	best: 3832.1813064 (0)	total: 47.5ms	remaining: 7m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 478.8255926
# bestIteration = 2251
#
# Shrink model to first 2252 iterations.
# 0:	learn: 3940.5646853	test: 3938.4930470	test1: 3918.7975533	best: 3918.7975533 (0)	total: 92.2ms	remaining: 15m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 469.4140289
# bestIteration = 2434
#
# Shrink model to first 2435 iterations.
# 0:	learn: 3918.9147618	test: 3915.4263392	test1: 4012.4659066	best: 4012.4659066 (0)	total: 58.8ms	remaining: 9m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 509.3321592
# bestIteration = 1807
#
# Shrink model to first 1808 iterations.
# 0:	learn: 3941.8136676	test: 3938.7403018	test1: 3906.9874912	best: 3906.9874912 (0)	total: 27.7ms	remaining: 4m 36s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 551.1155487
# bestIteration = 1650
#
# Shrink model to first 1651 iterations.
# 9 번째 모델---------------------------------------------------------------------
# 0:	learn: 66.9606070	test: 66.9366377	test1: 64.0875464	best: 64.0875464 (0)	total: 75.2ms	remaining: 12m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 29.20582848
# bestIteration = 1549
#
# Shrink model to first 1550 iterations.
# 0:	learn: 66.4813804	test: 66.4705987	test1: 66.1159180	best: 66.1159180 (0)	total: 39.5ms	remaining: 6m 34s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 27.87578615
# bestIteration = 1784
#
# Shrink model to first 1785 iterations.
# 0:	learn: 66.7021987	test: 66.6887511	test1: 65.0640559	best: 65.0640559 (0)	total: 50.5ms	remaining: 8m 25s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 30.27913847
# bestIteration = 1247
#
# Shrink model to first 1248 iterations.
# 0:	learn: 64.0976883	test: 64.0751916	test1: 75.1711938	best: 75.1711938 (0)	total: 41.1ms	remaining: 6m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 34.76090113
# bestIteration = 1443
#
# Shrink model to first 1444 iterations.
# 0:	learn: 67.6730808	test: 67.6574128	test1: 61.0167470	best: 61.0167470 (0)	total: 46.8ms	remaining: 7m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 31.23244159
# bestIteration = 737
#
# Shrink model to first 738 iterations.
# 10 번째 모델---------------------------------------------------------------------
# 0:	learn: 1009.1576286	test: 1008.6367971	test1: 1007.5063914	best: 1007.5063914 (0)	total: 68.6ms	remaining: 11m 26s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 95.25353621
# bestIteration = 1149
#
# Shrink model to first 1150 iterations.
# 0:	learn: 1010.8339719	test: 1010.4981360	test1: 1002.2690248	best: 1002.2690248 (0)	total: 60.9ms	remaining: 10m 8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 93.66980537
# bestIteration = 2250
#
# Shrink model to first 2251 iterations.
# 0:	learn: 1008.2247885	test: 1007.8347688	test1: 1013.5565276	best: 1013.5565276 (0)	total: 57.4ms	remaining: 9m 33s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 154.9965143
# bestIteration = 1543
#
# Shrink model to first 1544 iterations.
# 0:	learn: 1008.5913931	test: 1007.7558302	test1: 1010.6515055	best: 1010.6515055 (0)	total: 49ms	remaining: 8m 9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 151.4179902
# bestIteration = 839
#
# Shrink model to first 840 iterations.
# 0:	learn: 1007.7845866	test: 1007.3754761	test1: 1014.3671976	best: 1014.3671976 (0)	total: 25.1ms	remaining: 4m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 117.7941686
# bestIteration = 1781
#
# Shrink model to first 1782 iterations.
# 11 번째 모델---------------------------------------------------------------------
# 0:	learn: 1762.9267437	test: 1760.7081907	test1: 1757.3951194	best: 1757.3951194 (0)	total: 40.5ms	remaining: 6m 44s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 96.22922159
# bestIteration = 2615
#
# Shrink model to first 2616 iterations.
# 0:	learn: 1760.3944238	test: 1759.4519674	test1: 1752.3450572	best: 1752.3450572 (0)	total: 32.9ms	remaining: 5m 28s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 105.1141543
# bestIteration = 2111
#
# Shrink model to first 2112 iterations.
# 0:	learn: 1758.5690447	test: 1757.3062893	test1: 1764.8308731	best: 1764.8308731 (0)	total: 31.9ms	remaining: 5m 18s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 107.9363587
# bestIteration = 1895
#
# Shrink model to first 1896 iterations.
# 0:	learn: 1767.8094469	test: 1766.9703178	test1: 1739.9083937	best: 1739.9083937 (0)	total: 38.3ms	remaining: 6m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 128.2043285
# bestIteration = 1858
#
# Shrink model to first 1859 iterations.
# 0:	learn: 1751.2295517	test: 1750.2430273	test1: 1787.9305254	best: 1787.9305254 (0)	total: 46.6ms	remaining: 7m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 115.0922825
# bestIteration = 2436
#
# Shrink model to first 2437 iterations.
# 12 번째 모델---------------------------------------------------------------------
# 0:	learn: 1183.7021718	test: 1183.1144007	test1: 1175.9682037	best: 1175.9682037 (0)	total: 51.9ms	remaining: 8m 38s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 71.18805456
# bestIteration = 2113
#
# Shrink model to first 2114 iterations.
# 0:	learn: 1182.4435169	test: 1181.9071599	test1: 1181.1396202	best: 1181.1396202 (0)	total: 61.4ms	remaining: 10m 13s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 69.06519144
# bestIteration = 2130
#
# Shrink model to first 2131 iterations.
# 0:	learn: 1180.9873876	test: 1180.4409905	test1: 1191.0646638	best: 1191.0646638 (0)	total: 63.1ms	remaining: 10m 31s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 77.95359019
# bestIteration = 1921
#
# Shrink model to first 1922 iterations.
# 0:	learn: 1185.5362623	test: 1184.9548755	test1: 1175.4554961	best: 1175.4554961 (0)	total: 45.5ms	remaining: 7m 34s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 87.21908829
# bestIteration = 978
#
# Shrink model to first 979 iterations.
# 0:	learn: 1181.2720510	test: 1180.6910781	test1: 1193.2479992	best: 1193.2479992 (0)	total: 37.3ms	remaining: 6m 12s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 79.8615864
# bestIteration = 1489
#
# Shrink model to first 1490 iterations.
# 13 번째 모델---------------------------------------------------------------------
# 0:	learn: 310.5719510	test: 310.4309314	test1: 322.4793722	best: 322.4793722 (0)	total: 30.8ms	remaining: 5m 8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 47.91034186
# bestIteration = 1687
#
# Shrink model to first 1688 iterations.
# 0:	learn: 314.6781016	test: 314.1927434	test1: 307.2827827	best: 307.2827827 (0)	total: 71.7ms	remaining: 11m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 46.41010749
# bestIteration = 1039
#
# Shrink model to first 1040 iterations.
# 0:	learn: 313.5226182	test: 313.3288654	test1: 311.7706785	best: 311.7706785 (0)	total: 70.4ms	remaining: 11m 44s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 46.94673072
# bestIteration = 1156
#
# Shrink model to first 1157 iterations.
# 0:	learn: 313.3309959	test: 313.0751812	test1: 311.1035326	best: 311.1035326 (0)	total: 70.5ms	remaining: 11m 45s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 43.92379706
# bestIteration = 1858
#
# Shrink model to first 1859 iterations.
# 0:	learn: 313.2742872	test: 313.0831024	test1: 312.0964613	best: 312.0964613 (0)	total: 31.6ms	remaining: 5m 16s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 43.47881891
# bestIteration = 2062
#
# Shrink model to first 2063 iterations.
# 14 번째 모델---------------------------------------------------------------------
# 0:	learn: 482.2458047	test: 481.7301645	test1: 504.8883117	best: 504.8883117 (0)	total: 57.1ms	remaining: 9m 30s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 85.13175577
# bestIteration = 1382
#
# Shrink model to first 1383 iterations.
# 0:	learn: 488.4409274	test: 488.1392588	test1: 480.4348560	best: 480.4348560 (0)	total: 28.7ms	remaining: 4m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 91.01936932
# bestIteration = 1653
#
# Shrink model to first 1654 iterations.
# 0:	learn: 489.9010794	test: 489.0933990	test1: 476.1509663	best: 476.1509663 (0)	total: 37.9ms	remaining: 6m 19s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 85.36317479
# bestIteration = 1070
#
# Shrink model to first 1071 iterations.
# 0:	learn: 488.4483939	test: 487.7203316	test1: 482.4625473	best: 482.4625473 (0)	total: 39.5ms	remaining: 6m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 93.44644085
# bestIteration = 1592
#
# Shrink model to first 1593 iterations.
# 0:	learn: 486.3192285	test: 485.7614130	test1: 489.8684837	best: 489.8684837 (0)	total: 28.1ms	remaining: 4m 41s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 85.75891944
# bestIteration = 2135
#
# Shrink model to first 2136 iterations.
# 15 번째 모델---------------------------------------------------------------------
# 0:	learn: 427.9374864	test: 427.6119549	test1: 425.7627295	best: 425.7627295 (0)	total: 46.9ms	remaining: 7m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 215.6904194
# bestIteration = 769
#
# Shrink model to first 770 iterations.
# 0:	learn: 427.9031083	test: 427.5999055	test1: 427.7274174	best: 427.7274174 (0)	total: 43.9ms	remaining: 7m 18s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 207.2765954
# bestIteration = 1379
#
# Shrink model to first 1380 iterations.
# 0:	learn: 426.7365585	test: 426.3234609	test1: 432.1722317	best: 432.1722317 (0)	total: 57ms	remaining: 9m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 219.0926873
# bestIteration = 1896
#
# Shrink model to first 1897 iterations.
# 0:	learn: 426.1975315	test: 425.9929981	test1: 433.8341789	best: 433.8341789 (0)	total: 23.9ms	remaining: 3m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 229.7041813
# bestIteration = 406
#
# Shrink model to first 407 iterations.
# 0:	learn: 429.9467311	test: 429.7833212	test1: 418.8836111	best: 418.8836111 (0)	total: 58.8ms	remaining: 9m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 213.6602685
# bestIteration = 1319
#
# Shrink model to first 1320 iterations.
# 16 번째 모델---------------------------------------------------------------------
# 0:	learn: 137.6936788	test: 137.6769151	test1: 141.2445170	best: 141.2445170 (0)	total: 47.4ms	remaining: 7m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 20.04313171
# bestIteration = 1206
#
# Shrink model to first 1207 iterations.
# 0:	learn: 140.3505987	test: 140.2113336	test1: 130.7928384	best: 130.7928384 (0)	total: 37.2ms	remaining: 6m 11s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 21.38138066
# bestIteration = 1547
#
# Shrink model to first 1548 iterations.
# 0:	learn: 138.3094103	test: 138.1990101	test1: 138.8131486	best: 138.8131486 (0)	total: 24.5ms	remaining: 4m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 22.65521417
# bestIteration = 1581
#
# Shrink model to first 1582 iterations.
# 0:	learn: 136.9611642	test: 136.8579373	test1: 143.1408570	best: 143.1408570 (0)	total: 29.5ms	remaining: 4m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 21.93634854
# bestIteration = 1597
#
# Shrink model to first 1598 iterations.
# 0:	learn: 138.7025904	test: 138.4536746	test1: 137.4866588	best: 137.4866588 (0)	total: 50.6ms	remaining: 8m 25s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 22.98742534
# bestIteration = 1742
#
# Shrink model to first 1743 iterations.
# 17 번째 모델---------------------------------------------------------------------
# 0:	learn: 491.0081685	test: 490.3832497	test1: 498.6323496	best: 498.6323496 (0)	total: 49.3ms	remaining: 8m 12s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 60.26161431
# bestIteration = 1675
#
# Shrink model to first 1676 iterations.
# 0:	learn: 493.3412462	test: 493.0085953	test1: 488.0317314	best: 488.0317314 (0)	total: 51.9ms	remaining: 8m 39s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 55.62253644
# bestIteration = 802
#
# Shrink model to first 803 iterations.
# 0:	learn: 491.8961871	test: 491.6968363	test1: 492.8941614	best: 492.8941614 (0)	total: 49.5ms	remaining: 8m 15s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 56.90960487
# bestIteration = 1127
#
# Shrink model to first 1128 iterations.
# 0:	learn: 490.1833827	test: 490.0374606	test1: 499.6132232	best: 499.6132232 (0)	total: 17.9ms	remaining: 2m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 53.93807558
# bestIteration = 2388
#
# Shrink model to first 2389 iterations.
# 0:	learn: 494.3999999	test: 494.0486428	test1: 481.2031943	best: 481.2031943 (0)	total: 29.6ms	remaining: 4m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 75.71505482
# bestIteration = 712
#
# Shrink model to first 713 iterations.
# 18 번째 모델---------------------------------------------------------------------
# 0:	learn: 932.9124802	test: 932.3706888	test1: 905.4654319	best: 905.4654319 (0)	total: 47.4ms	remaining: 7m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 181.8706629
# bestIteration = 2125
#
# Shrink model to first 2126 iterations.
# 0:	learn: 933.8848889	test: 933.4038482	test1: 902.3549947	best: 902.3549947 (0)	total: 65.3ms	remaining: 10m 52s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 188.5677376
# bestIteration = 1861
#
# Shrink model to first 1862 iterations.
# 0:	learn: 924.8371000	test: 923.4474607	test1: 937.7405635	best: 937.7405635 (0)	total: 38.8ms	remaining: 6m 28s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 208.7172637
# bestIteration = 1581
#
# Shrink model to first 1582 iterations.
# 0:	learn: 917.9861139	test: 916.6798556	test1: 962.4928179	best: 962.4928179 (0)	total: 49.1ms	remaining: 8m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 198.3695043
# bestIteration = 1276
#
# Shrink model to first 1277 iterations.
# 0:	learn: 927.5989601	test: 927.2215540	test1: 927.5424094	best: 927.5424094 (0)	total: 24.7ms	remaining: 4m 7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 198.9598414
# bestIteration = 1313
#
# Shrink model to first 1314 iterations.
# 19 번째 모델---------------------------------------------------------------------
# 0:	learn: 233.1591403	test: 232.9947846	test1: 219.4588379	best: 219.4588379 (0)	total: 63.8ms	remaining: 10m 37s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 26.96576616
# bestIteration = 2798
#
# Shrink model to first 2799 iterations.
# 0:	learn: 229.4806737	test: 229.3250677	test1: 233.6618079	best: 233.6618079 (0)	total: 68.5ms	remaining: 11m 24s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 32.2692559
# bestIteration = 1917
#
# Shrink model to first 1918 iterations.
# 0:	learn: 229.9369164	test: 229.7165462	test1: 231.7660858	best: 231.7660858 (0)	total: 31ms	remaining: 5m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 26.68924929
# bestIteration = 2130
#
# Shrink model to first 2131 iterations.
# 0:	learn: 233.8788000	test: 233.5149018	test1: 215.8860196	best: 215.8860196 (0)	total: 50.2ms	remaining: 8m 21s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 27.81526928
# bestIteration = 2556
#
# Shrink model to first 2557 iterations.
# 0:	learn: 225.3950438	test: 225.1599639	test1: 249.2106363	best: 249.2106363 (0)	total: 30.1ms	remaining: 5m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 33.06629795
# bestIteration = 2351
#
# Shrink model to first 2352 iterations.
# 20 번째 모델---------------------------------------------------------------------
# 0:	learn: 375.6987288	test: 375.7199235	test1: 351.3491294	best: 351.3491294 (0)	total: 44.9ms	remaining: 7m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 51.51206025
# bestIteration = 3252
#
# Shrink model to first 3253 iterations.
# 0:	learn: 368.3601674	test: 367.9920618	test1: 380.4212980	best: 380.4212980 (0)	total: 30.5ms	remaining: 5m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 53.11137481
# bestIteration = 2640
#
# Shrink model to first 2641 iterations.
# 0:	learn: 368.6901720	test: 368.7094470	test1: 380.3764214	best: 380.3764214 (0)	total: 52.6ms	remaining: 8m 45s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 50.65984995
# bestIteration = 2955
#
# Shrink model to first 2956 iterations.
# 0:	learn: 375.2853553	test: 375.2201494	test1: 352.8555438	best: 352.8555438 (0)	total: 27ms	remaining: 4m 30s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 47.50230846
# bestIteration = 3768
#
# Shrink model to first 3769 iterations.
# 0:	learn: 366.4575697	test: 366.3058591	test1: 388.5169891	best: 388.5169891 (0)	total: 43.7ms	remaining: 7m 16s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 50.97212569
# bestIteration = 2279
#
# Shrink model to first 2280 iterations.
# 21 번째 모델---------------------------------------------------------------------
# 0:	learn: 431.5615158	test: 431.1944407	test1: 408.9169293	best: 408.9169293 (0)	total: 29.7ms	remaining: 4m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 50.98353104
# bestIteration = 2855
#
# Shrink model to first 2856 iterations.
# 0:	learn: 425.7804256	test: 425.6366615	test1: 430.3198350	best: 430.3198350 (0)	total: 40.3ms	remaining: 6m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 55.15748107
# bestIteration = 2897
#
# Shrink model to first 2898 iterations.
# 0:	learn: 422.8484963	test: 422.4039603	test1: 443.6617267	best: 443.6617267 (0)	total: 87.7ms	remaining: 14m 37s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 49.27497258
# bestIteration = 2725
#
# Shrink model to first 2726 iterations.
# 0:	learn: 432.8077556	test: 432.4577854	test1: 401.1390056	best: 401.1390056 (0)	total: 24.5ms	remaining: 4m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 49.2080337
# bestIteration = 2725
#
# Shrink model to first 2726 iterations.
# 0:	learn: 421.3067981	test: 421.0698901	test1: 448.4398943	best: 448.4398943 (0)	total: 39.8ms	remaining: 6m 37s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 59.1603636
# bestIteration = 2461
#
# Shrink model to first 2462 iterations.
# 22 번째 모델---------------------------------------------------------------------
# 0:	learn: 251.8039828	test: 251.5892365	test1: 268.2692704	best: 268.2692704 (0)	total: 57.2ms	remaining: 9m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 30.91702297
# bestIteration = 1813
#
# Shrink model to first 1814 iterations.
# 0:	learn: 257.0057307	test: 256.7248387	test1: 247.9635300	best: 247.9635300 (0)	total: 42ms	remaining: 6m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 29.59806537
# bestIteration = 1787
#
# Shrink model to first 1788 iterations.
# 0:	learn: 255.1258961	test: 254.8260169	test1: 254.6220554	best: 254.6220554 (0)	total: 54.4ms	remaining: 9m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 31.39149169
# bestIteration = 1592
#
# Shrink model to first 1593 iterations.
# 0:	learn: 256.1423139	test: 255.6295187	test1: 250.2812711	best: 250.2812711 (0)	total: 28.3ms	remaining: 4m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 30.61529386
# bestIteration = 2240
#
# Shrink model to first 2241 iterations.
# 0:	learn: 255.3068355	test: 255.3401048	test1: 253.0464595	best: 253.0464595 (0)	total: 46.4ms	remaining: 7m 44s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 29.38414196
# bestIteration = 2341
#
# Shrink model to first 2342 iterations.
# 23 번째 모델---------------------------------------------------------------------
# 0:	learn: 432.8824461	test: 432.8824461	test1: 463.9782894	best: 463.9782894 (0)	total: 51.4ms	remaining: 8m 33s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 155.1159536
# bestIteration = 1142
#
# Shrink model to first 1143 iterations.
# 0:	learn: 440.1844850	test: 439.9973987	test1: 428.8629077	best: 428.8629077 (0)	total: 24.7ms	remaining: 4m 6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 139.4676613
# bestIteration = 1143
#
# Shrink model to first 1144 iterations.
# 0:	learn: 438.4845046	test: 438.3580282	test1: 435.2633792	best: 435.2633792 (0)	total: 24ms	remaining: 4m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 141.0084234
# bestIteration = 657
#
# Shrink model to first 658 iterations.
# 0:	learn: 438.9884000	test: 438.9884000	test1: 439.8562327	best: 439.8562327 (0)	total: 23.9ms	remaining: 3m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 149.0251838
# bestIteration = 1129
#
# Shrink model to first 1130 iterations.
# 0:	learn: 441.4081413	test: 441.2981783	test1: 423.5609278	best: 423.5609278 (0)	total: 24.1ms	remaining: 4m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 137.6627519
# bestIteration = 654
#
# Shrink model to first 655 iterations.
# 24 번째 모델---------------------------------------------------------------------
# 0:	learn: 400.0349076	test: 400.0349076	test1: 399.8803291	best: 399.8803291 (0)	total: 38.7ms	remaining: 6m 26s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 101.2981095
# bestIteration = 1367
#
# Shrink model to first 1368 iterations.
# 0:	learn: 404.6755838	test: 404.5831588	test1: 376.0163279	best: 376.0163279 (0)	total: 29.3ms	remaining: 4m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 113.6173823
# bestIteration = 826
#
# Shrink model to first 827 iterations.
# 0:	learn: 400.5271560	test: 400.5271560	test1: 398.1699318	best: 398.1699318 (0)	total: 55ms	remaining: 9m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 112.4866155
# bestIteration = 1729
#
# Shrink model to first 1730 iterations.
# 0:	learn: 393.7757217	test: 393.7757217	test1: 423.7994858	best: 423.7994858 (0)	total: 38.2ms	remaining: 6m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 114.7838297
# bestIteration = 1204
#
# Shrink model to first 1205 iterations.
# 0:	learn: 399.8347111	test: 399.8347111	test1: 400.8571773	best: 400.8571773 (0)	total: 39ms	remaining: 6m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 125.3693961
# bestIteration = 435
#
# Shrink model to first 436 iterations.
# 25 번째 모델---------------------------------------------------------------------
# 0:	learn: 529.9458863	test: 529.1783944	test1: 581.5942522	best: 581.5942522 (0)	total: 42.3ms	remaining: 7m 2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 94.56646148
# bestIteration = 1801
#
# Shrink model to first 1802 iterations.
# 0:	learn: 542.4406607	test: 541.9850455	test1: 530.2164842	best: 530.2164842 (0)	total: 24.3ms	remaining: 4m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 90.48495009
# bestIteration = 1466
#
# Shrink model to first 1467 iterations.
# 0:	learn: 547.9796035	test: 547.2203887	test1: 507.1504866	best: 507.1504866 (0)	total: 29.9ms	remaining: 4m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 91.27553322
# bestIteration = 1680
#
# Shrink model to first 1681 iterations.
# 0:	learn: 538.5269989	test: 538.3686262	test1: 540.3301351	best: 540.3301351 (0)	total: 38.8ms	remaining: 6m 28s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 106.3062737
# bestIteration = 1194
#
# Shrink model to first 1195 iterations.
# 0:	learn: 541.0899088	test: 540.6120136	test1: 537.7755259	best: 537.7755259 (0)	total: 24.6ms	remaining: 4m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 109.7666297
# bestIteration = 1843
#
# Shrink model to first 1844 iterations.
# 26 번째 모델---------------------------------------------------------------------
# 0:	learn: 784.7297422	test: 784.3781881	test1: 836.5529758	best: 836.5529758 (0)	total: 36ms	remaining: 5m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 94.75206039
# bestIteration = 2432
#
# Shrink model to first 2433 iterations.
# 0:	learn: 802.3172440	test: 800.9512202	test1: 764.7221317	best: 764.7221317 (0)	total: 73.9ms	remaining: 12m 19s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 88.85143335
# bestIteration = 2320
#
# Shrink model to first 2321 iterations.
# 0:	learn: 793.5709495	test: 792.5145324	test1: 797.8459206	best: 797.8459206 (0)	total: 39.6ms	remaining: 6m 36s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 99.37069835
# bestIteration = 2087
#
# Shrink model to first 2088 iterations.
# 0:	learn: 796.8488883	test: 794.9668909	test1: 782.2993363	best: 782.2993363 (0)	total: 55.5ms	remaining: 9m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 89.62093888
# bestIteration = 2750
#
# Shrink model to first 2751 iterations.
# 0:	learn: 795.1555177	test: 794.8976396	test1: 787.0011559	best: 787.0011559 (0)	total: 37.4ms	remaining: 6m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 93.05167293
# bestIteration = 2720
#
# Shrink model to first 2721 iterations.
# 27 번째 모델---------------------------------------------------------------------
# 0:	learn: 214.9771951	test: 214.9553869	test1: 223.0645856	best: 223.0645856 (0)	total: 59.5ms	remaining: 9m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 56.17762984
# bestIteration = 1651
#
# Shrink model to first 1652 iterations.
# 0:	learn: 219.2373560	test: 219.2373560	test1: 208.2143814	best: 208.2143814 (0)	total: 55.5ms	remaining: 9m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 53.850111
# bestIteration = 2052
#
# Shrink model to first 2053 iterations.
# 0:	learn: 216.7938745	test: 216.7422760	test1: 215.6973809	best: 215.6973809 (0)	total: 47.1ms	remaining: 7m 51s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 46.90777051
# bestIteration = 1876
#
# Shrink model to first 1877 iterations.
# 0:	learn: 217.1640812	test: 217.1640812	test1: 216.7086364	best: 216.7086364 (0)	total: 51.9ms	remaining: 8m 38s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 60.53326749
# bestIteration = 1176
#
# Shrink model to first 1177 iterations.
# 0:	learn: 216.1449815	test: 216.1449815	test1: 221.2289571	best: 221.2289571 (0)	total: 34.4ms	remaining: 5m 43s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 51.9564647
# bestIteration = 2911
#
# Shrink model to first 2912 iterations.
# 28 번째 모델---------------------------------------------------------------------
# 0:	learn: 553.3881461	test: 553.2210237	test1: 557.6142486	best: 557.6142486 (0)	total: 33.7ms	remaining: 5m 37s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 87.97738244
# bestIteration = 1311
#
# Shrink model to first 1312 iterations.
# 0:	learn: 554.2878223	test: 553.8930093	test1: 554.8398420	best: 554.8398420 (0)	total: 26.8ms	remaining: 4m 27s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 84.26191589
# bestIteration = 1091
#
# Shrink model to first 1092 iterations.
# 0:	learn: 551.1264487	test: 550.5491398	test1: 566.0520992	best: 566.0520992 (0)	total: 38.1ms	remaining: 6m 20s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 85.03258032
# bestIteration = 1248
#
# Shrink model to first 1249 iterations.
# 0:	learn: 560.0169641	test: 559.6561797	test1: 533.5112405	best: 533.5112405 (0)	total: 38.6ms	remaining: 6m 26s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 85.61770087
# bestIteration = 1188
#
# Shrink model to first 1189 iterations.
# 0:	learn: 552.6148245	test: 552.7958917	test1: 562.7328129	best: 562.7328129 (0)	total: 37.1ms	remaining: 6m 11s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 86.57371902
# bestIteration = 1344
#
# Shrink model to first 1345 iterations.
# 29 번째 모델---------------------------------------------------------------------
# 0:	learn: 307.6185363	test: 307.5444776	test1: 319.4644357	best: 319.4644357 (0)	total: 82.4ms	remaining: 13m 43s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 68.76611551
# bestIteration = 1037
#
# Shrink model to first 1038 iterations.
# 0:	learn: 308.7014070	test: 308.5515325	test1: 315.3988389	best: 315.3988389 (0)	total: 27.1ms	remaining: 4m 31s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 68.73002078
# bestIteration = 1493
#
# Shrink model to first 1494 iterations.
# 0:	learn: 310.6863099	test: 310.6310912	test1: 305.5195851	best: 305.5195851 (0)	total: 37.1ms	remaining: 6m 11s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 63.29694124
# bestIteration = 1590
#
# Shrink model to first 1591 iterations.
# 0:	learn: 312.8169461	test: 312.6181286	test1: 297.6546329	best: 297.6546329 (0)	total: 70.1ms	remaining: 11m 41s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 68.45219484
# bestIteration = 2488
#
# Shrink model to first 2489 iterations.
# 0:	learn: 309.5096156	test: 309.4488974	test1: 312.1606490	best: 312.1606490 (0)	total: 36.5ms	remaining: 6m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 67.73319351
# bestIteration = 1580
#
# Shrink model to first 1581 iterations.
# 30 번째 모델---------------------------------------------------------------------
# 0:	learn: 1659.1354524	test: 1657.8810890	test1: 1653.7470165	best: 1653.7470165 (0)	total: 43ms	remaining: 7m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 406.4828993
# bestIteration = 1525
#
# Shrink model to first 1526 iterations.
# 0:	learn: 1667.5060607	test: 1666.2140957	test1: 1619.3323241	best: 1619.3323241 (0)	total: 25.5ms	remaining: 4m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 335.9214201
# bestIteration = 2963
#
# Shrink model to first 2964 iterations.
# 0:	learn: 1637.5907189	test: 1636.0388014	test1: 1736.7557749	best: 1736.7557749 (0)	total: 24.3ms	remaining: 4m 2s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 383.7531585
# bestIteration = 2023
#
# Shrink model to first 2024 iterations.
# 0:	learn: 1673.2541614	test: 1671.7807718	test1: 1590.4478780	best: 1590.4478780 (0)	total: 24.1ms	remaining: 4m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 391.3822258
# bestIteration = 972
#
# Shrink model to first 973 iterations.
# 0:	learn: 1649.6794015	test: 1648.5514028	test1: 1686.8821111	best: 1686.8821111 (0)	total: 47.7ms	remaining: 7m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 396.9511919
# bestIteration = 1381
#
# Shrink model to first 1382 iterations.
# 31 번째 모델---------------------------------------------------------------------
# 0:	learn: 231.6005605	test: 231.6005605	test1: 216.3951399	best: 216.3951399 (0)	total: 38ms	remaining: 6m 19s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 65.11347647
# bestIteration = 196
#
# Shrink model to first 197 iterations.
# 0:	learn: 233.4691012	test: 233.4691012	test1: 208.0460550	best: 208.0460550 (0)	total: 24.4ms	remaining: 4m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 40.10755307
# bestIteration = 1342
#
# Shrink model to first 1343 iterations.
# 0:	learn: 231.7695105	test: 231.7695105	test1: 215.6867993	best: 215.6867993 (0)	total: 48.1ms	remaining: 8m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 56.64778888
# bestIteration = 347
#
# Shrink model to first 348 iterations.
# 0:	learn: 213.7239837	test: 213.7239837	test1: 279.9432893	best: 279.9432893 (0)	total: 37.9ms	remaining: 6m 19s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 203.3765316
# bestIteration = 683
#
# Shrink model to first 684 iterations.
# 0:	learn: 231.7900991	test: 231.7900991	test1: 215.5438872	best: 215.5438872 (0)	total: 58.8ms	remaining: 9m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 41.13091417
# bestIteration = 707
#
# Shrink model to first 708 iterations.
# 32 번째 모델---------------------------------------------------------------------
# 0:	learn: 36.3586473	test: 36.3586473	test1: 38.4737751	best: 38.4737751 (0)	total: 30.1ms	remaining: 5m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 9.509034587
# bestIteration = 1326
#
# Shrink model to first 1327 iterations.
# 0:	learn: 37.0606644	test: 37.0606644	test1: 35.7223540	best: 35.7223540 (0)	total: 40.8ms	remaining: 6m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 9.446497563
# bestIteration = 1386
#
# Shrink model to first 1387 iterations.
# 0:	learn: 36.8815260	test: 36.8815260	test1: 36.4097260	best: 36.4097260 (0)	total: 23.9ms	remaining: 3m 58s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 10.0584168
# bestIteration = 1595
#
# Shrink model to first 1596 iterations.
# 0:	learn: 36.8081402	test: 36.8081402	test1: 36.7821845	best: 36.7821845 (0)	total: 25.5ms	remaining: 4m 15s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 9.946108396
# bestIteration = 941
#
# Shrink model to first 942 iterations.
# 0:	learn: 36.8164189	test: 36.8164189	test1: 36.7234624	best: 36.7234624 (0)	total: 28.3ms	remaining: 4m 43s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 9.412980207
# bestIteration = 1382
#
# Shrink model to first 1383 iterations.
# 33 번째 모델---------------------------------------------------------------------
# 0:	learn: 122.4129939	test: 122.2684781	test1: 119.0073178	best: 119.0073178 (0)	total: 40.7ms	remaining: 6m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 33.56641906
# bestIteration = 220
#
# Shrink model to first 221 iterations.
# 0:	learn: 123.6145277	test: 123.4660302	test1: 113.3116494	best: 113.3116494 (0)	total: 28.1ms	remaining: 4m 41s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 21.14929826
# bestIteration = 1335
#
# Shrink model to first 1336 iterations.
# 0:	learn: 123.1703315	test: 123.0168276	test1: 115.5729704	best: 115.5729704 (0)	total: 39.7ms	remaining: 6m 36s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 29.84384019
# bestIteration = 231
#
# Shrink model to first 232 iterations.
# 0:	learn: 115.6088327	test: 115.3691709	test1: 143.1156740	best: 143.1156740 (0)	total: 35.7ms	remaining: 5m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 94.76587745
# bestIteration = 497
#
# Shrink model to first 498 iterations.
# 0:	learn: 123.4569913	test: 123.3372028	test1: 114.3654376	best: 114.3654376 (0)	total: 42.5ms	remaining: 7m 4s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 28.17979405
# bestIteration = 344
#
# Shrink model to first 345 iterations.
# 34 번째 모델---------------------------------------------------------------------
# 0:	learn: 366.7803356	test: 366.6019237	test1: 370.0234313	best: 370.0234313 (0)	total: 37.1ms	remaining: 6m 11s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 132.241105
# bestIteration = 1726
#
# Shrink model to first 1727 iterations.
# 0:	learn: 370.7254358	test: 370.5937983	test1: 353.0590442	best: 353.0590442 (0)	total: 41.5ms	remaining: 6m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 139.1192302
# bestIteration = 980
#
# Shrink model to first 981 iterations.
# 0:	learn: 367.3213824	test: 367.0709190	test1: 367.5651699	best: 367.5651699 (0)	total: 43.9ms	remaining: 7m 18s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 156.8204105
# bestIteration = 1202
#
# Shrink model to first 1203 iterations.
# 0:	learn: 372.4664818	test: 372.3910088	test1: 347.7802849	best: 347.7802849 (0)	total: 50.9ms	remaining: 8m 28s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 124.544029
# bestIteration = 1401
#
# Shrink model to first 1402 iterations.
# 0:	learn: 360.2219109	test: 359.9063145	test1: 397.4331707	best: 397.4331707 (0)	total: 23.8ms	remaining: 3m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 114.6294532
# bestIteration = 1197
#
# Shrink model to first 1198 iterations.
# 35 번째 모델---------------------------------------------------------------------
# 0:	learn: 819.4612659	test: 817.5742815	test1: 873.9983199	best: 873.9983199 (0)	total: 26ms	remaining: 4m 20s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 103.6822848
# bestIteration = 1107
#
# Shrink model to first 1108 iterations.
# 0:	learn: 833.0259225	test: 831.8696444	test1: 816.1417546	best: 816.1417546 (0)	total: 40.7ms	remaining: 6m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 94.69024975
# bestIteration = 1165
#
# Shrink model to first 1166 iterations.
# 0:	learn: 835.4734490	test: 834.3957229	test1: 806.2776251	best: 806.2776251 (0)	total: 51.3ms	remaining: 8m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 95.33237492
# bestIteration = 1490
#
# Shrink model to first 1491 iterations.
# 0:	learn: 824.2320110	test: 823.8920426	test1: 848.4781187	best: 848.4781187 (0)	total: 36.9ms	remaining: 6m 9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 99.88097248
# bestIteration = 2556
#
# Shrink model to first 2557 iterations.
# 0:	learn: 837.4965482	test: 836.7036168	test1: 801.4394338	best: 801.4394338 (0)	total: 33.2ms	remaining: 5m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 135.3759766
# bestIteration = 1391
#
# Shrink model to first 1392 iterations.
# 36 번째 모델---------------------------------------------------------------------
# 0:	learn: 220.7332138	test: 220.6018030	test1: 228.3127170	best: 228.3127170 (0)	total: 65.5ms	remaining: 10m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 53.64199266
# bestIteration = 986
#
# Shrink model to first 987 iterations.
# 0:	learn: 222.4316441	test: 222.3342871	test1: 221.6689263	best: 221.6689263 (0)	total: 27.8ms	remaining: 4m 37s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 43.15245304
# bestIteration = 797
#
# Shrink model to first 798 iterations.
# 0:	learn: 221.7186198	test: 221.6082614	test1: 224.6977822	best: 224.6977822 (0)	total: 48.7ms	remaining: 8m 7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 35.14926062
# bestIteration = 1029
#
# Shrink model to first 1030 iterations.
# 0:	learn: 222.3311199	test: 222.2201845	test1: 222.6868399	best: 222.6868399 (0)	total: 42.9ms	remaining: 7m 9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 47.16814276
# bestIteration = 708
#
# Shrink model to first 709 iterations.
# 0:	learn: 224.1659075	test: 224.0910127	test1: 214.4366769	best: 214.4366769 (0)	total: 32.3ms	remaining: 5m 23s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 43.45786953
# bestIteration = 612
#
# Shrink model to first 613 iterations.
# 37 번째 모델---------------------------------------------------------------------
# ...
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 184.867621
# bestIteration = 1751
#
# Shrink model to first 1752 iterations.
# 0:	learn: 1311.7027959	test: 1311.2008952	test1: 1305.7737099	best: 1305.7737099 (0)	total: 60.9ms	remaining: 10m 8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 185.8754381
# bestIteration = 1377
#
# Shrink model to first 1378 iterations.
# 0:	learn: 1305.1011899	test: 1304.7711733	test1: 1331.5354186	best: 1331.5354186 (0)	total: 38.2ms	remaining: 6m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 213.7083954
# bestIteration = 1458
#
# Shrink model to first 1459 iterations.
# 41 번째 모델---------------------------------------------------------------------
# 0:	learn: 679.1638327	test: 678.8513881	test1: 690.0118057	best: 690.0118057 (0)	total: 38.5ms	remaining: 6m 24s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 58.48117004
# bestIteration = 1875
#
# Shrink model to first 1876 iterations.
# 0:	learn: 680.5477790	test: 680.2426165	test1: 685.5027509	best: 685.5027509 (0)	total: 80.9ms	remaining: 13m 28s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 56.91930008
# bestIteration = 1917
#
# Shrink model to first 1918 iterations.
# 0:	learn: 680.4981361	test: 680.1717426	test1: 684.1581694	best: 684.1581694 (0)	total: 34ms	remaining: 5m 39s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 66.44938292
# bestIteration = 1738
#
# Shrink model to first 1739 iterations.
# 0:	learn: 685.0020520	test: 684.7172317	test1: 665.3740333	best: 665.3740333 (0)	total: 40.8ms	remaining: 6m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 61.57312249
# bestIteration = 2074
#
# Shrink model to first 2075 iterations.
# 0:	learn: 680.7449111	test: 680.3896528	test1: 682.5456141	best: 682.5456141 (0)	total: 23.3ms	remaining: 3m 52s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 64.49268659
# bestIteration = 2209
#
# Shrink model to first 2210 iterations.
# 42 번째 모델---------------------------------------------------------------------
# 0:	learn: 1463.1563218	test: 1462.4087392	test1: 1410.6624907	best: 1410.6624907 (0)	total: 35ms	remaining: 5m 49s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 323.0417377
# bestIteration = 1919
#
# Shrink model to first 1920 iterations.
# 0:	learn: 1443.4498471	test: 1442.7850687	test1: 1489.1594368	best: 1489.1594368 (0)	total: 49.1ms	remaining: 8m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 337.200941
# bestIteration = 2292
#
# Shrink model to first 2293 iterations.
# 0:	learn: 1447.9885951	test: 1446.8894668	test1: 1471.5934391	best: 1471.5934391 (0)	total: 33.3ms	remaining: 5m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 365.1557374
# bestIteration = 2250
#
# Shrink model to first 2251 iterations.
# 0:	learn: 1457.0145518	test: 1456.4925773	test1: 1440.9889360	best: 1440.9889360 (0)	total: 47.4ms	remaining: 7m 54s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 320.2844558
# bestIteration = 2062
#
# Shrink model to first 2063 iterations.
# 0:	learn: 1452.6969296	test: 1451.8734551	test1: 1453.5755666	best: 1453.5755666 (0)	total: 35.2ms	remaining: 5m 52s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 348.1037469
# bestIteration = 1633
#
# Shrink model to first 1634 iterations.
# 43 번째 모델---------------------------------------------------------------------
# 0:	learn: 497.4092023	test: 496.9547019	test1: 526.4602235	best: 526.4602235 (0)	total: 33.4ms	remaining: 5m 34s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 99.94923836
# bestIteration = 1377
#
# Shrink model to first 1378 iterations.
# 0:	learn: 506.3233836	test: 506.1407613	test1: 490.9729822	best: 490.9729822 (0)	total: 47.7ms	remaining: 7m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 98.20239681
# bestIteration = 1704
#
# Shrink model to first 1705 iterations.
# 0:	learn: 501.7938396	test: 501.5453075	test1: 508.8097592	best: 508.8097592 (0)	total: 52.1ms	remaining: 8m 40s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 99.93458538
# bestIteration = 1858
#
# Shrink model to first 1859 iterations.
# 0:	learn: 506.4206850	test: 506.0180747	test1: 490.6017367	best: 490.6017367 (0)	total: 31.8ms	remaining: 5m 17s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 111.3736446
# bestIteration = 1212
#
# Shrink model to first 1213 iterations.
# 0:	learn: 504.3609467	test: 503.9205743	test1: 499.3961344	best: 499.3961344 (0)	total: 48.2ms	remaining: 8m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 94.08765312
# bestIteration = 1688
#
# Shrink model to first 1689 iterations.
# 44 번째 모델---------------------------------------------------------------------
# 0:	learn: 480.3717170	test: 480.1135651	test1: 494.2480219	best: 494.2480219 (0)	total: 43.5ms	remaining: 7m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 46.72762086
# bestIteration = 3263
#
# Shrink model to first 3264 iterations.
# 0:	learn: 485.6330971	test: 484.5908257	test1: 478.7087534	best: 478.7087534 (0)	total: 24.3ms	remaining: 4m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 54.26914287
# bestIteration = 1712
#
# Shrink model to first 1713 iterations.
# 0:	learn: 481.4808623	test: 481.2625442	test1: 494.0654856	best: 494.0654856 (0)	total: 40.7ms	remaining: 6m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 47.05800191
# bestIteration = 3542
#
# Shrink model to first 3543 iterations.
# 0:	learn: 487.0455007	test: 486.6602857	test1: 466.4860960	best: 466.4860960 (0)	total: 28.1ms	remaining: 4m 41s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 76.63318436
# bestIteration = 1727
#
# Shrink model to first 1728 iterations.
# 0:	learn: 449.3953390	test: 448.6753917	test1: 441.9316399	best: 441.9316399 (0)	total: 53.6ms	remaining: 8m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 63.47333816
# bestIteration = 1631
#
# Shrink model to first 1632 iterations.
# 0:	learn: 446.0484517	test: 445.1693341	test1: 458.1586192	best: 458.1586192 (0)	total: 64.2ms	remaining: 10m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 58.33599799
# bestIteration = 2193
#
# Shrink model to first 2194 iterations.
# 0:	learn: 449.3404972	test: 448.4458177	test1: 444.4076852	best: 444.4076852 (0)	total: 31.5ms	remaining: 5m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 64.03207437
# bestIteration = 2371
#
# Shrink model to first 2372 iterations.
# 54 번째 모델---------------------------------------------------------------------
# 0:	learn: 1207.6302067	test: 1206.9352222	test1: 1256.8937243	best: 1256.8937243 (0)	total: 58.3ms	remaining: 9m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 203.6863786
# bestIteration = 2651
#
# Shrink model to first 2652 iterations.
# 0:	learn: 1219.9653518	test: 1219.2257128	test1: 1208.2464915	best: 1208.2464915 (0)	total: 24.7ms	remaining: 4m 6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 223.2601088
# bestIteration = 1770
#
# Shrink model to first 1771 iterations.
# 0:	learn: 1225.6865550	test: 1224.9951712	test1: 1186.8459674	best: 1186.8459674 (0)	total: 18ms	remaining: 3m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 199.0156165
# bestIteration = 1853
#
# Shrink model to first 1854 iterations.
# 0:	learn: 1211.7679884	test: 1211.2068249	test1: 1237.6133914	best: 1237.6133914 (0)	total: 48.7ms	remaining: 8m 7s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 190.4877765
# bestIteration = 2115
#
# Shrink model to first 2116 iterations.
# 0:	learn: 1221.6979898	test: 1221.0131862	test1: 1199.5417939	best: 1199.5417939 (0)	total: 24.2ms	remaining: 4m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 225.5118105
# bestIteration = 2391
#
# Shrink model to first 2392 iterations.
# 55 번째 모델---------------------------------------------------------------------
# 0:	learn: 644.1158011	test: 644.0256062	test1: 681.1000191	best: 681.1000191 (0)	total: 24.6ms	remaining: 4m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 87.82476144
# bestIteration = 2191
#
# Shrink model to first 2192 iterations.
# 0:	learn: 653.1773822	test: 652.8563105	test1: 642.7161453	best: 642.7161453 (0)	total: 53.1ms	remaining: 8m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 70.560796
# bestIteration = 1811
#
# Shrink model to first 1812 iterations.
# 0:	learn: 654.5610535	test: 654.0108449	test1: 635.0653881	best: 635.0653881 (0)	total: 39.1ms	remaining: 6m 30s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 71.9604711
# bestIteration = 3106
#
# Shrink model to first 3107 iterations.
# 0:	learn: 651.6168684	test: 651.0321440	test1: 649.6237870	best: 649.6237870 (0)	total: 32.6ms	remaining: 5m 25s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 88.24658653
# bestIteration = 1925
#
# Shrink model to first 1926 iterations.
# 0:	learn: 652.2231622	test: 651.7787155	test1: 647.0018946	best: 647.0018946 (0)	total: 41.7ms	remaining: 6m 56s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 95.77414882
# bestIteration = 2148
#
# Shrink model to first 2149 iterations.
# 56 번째 모델---------------------------------------------------------------------
# 0:	learn: 256.0443262	test: 255.8476498	test1: 272.6273388	best: 272.6273388 (0)	total: 104ms	remaining: 17m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 44.46329931
# bestIteration = 1944
#
# Shrink model to first 1945 iterations.
# 0:	learn: 259.6022107	test: 259.4944089	test1: 259.5286712	best: 259.5286712 (0)	total: 80.2ms	remaining: 13m 21s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 41.3604839
# bestIteration = 1838
#
# Shrink model to first 1839 iterations.
# 0:	learn: 262.5169150	test: 262.3752800	test1: 246.6580911	best: 246.6580911 (0)	total: 38.2ms	remaining: 6m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 47.95170872
# bestIteration = 1166
#
# Shrink model to first 1167 iterations.
# 0:	learn: 260.1231890	test: 260.1938543	test1: 256.9864964	best: 256.9864964 (0)	total: 47.6ms	remaining: 7m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 45.07181888
# bestIteration = 1510
#
# Shrink model to first 1511 iterations.
# 0:	learn: 259.0042829	test: 258.9415634	test1: 261.0143914	best: 261.0143914 (0)	total: 55.7ms	remaining: 9m 16s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 52.05473961
# bestIteration = 1172
#
# Shrink model to first 1173 iterations.
# 57 번째 모델---------------------------------------------------------------------
# 0:	learn: 636.3254161	test: 636.2095682	test1: 665.3838618	best: 665.3838618 (0)	total: 41.5ms	remaining: 6m 55s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 184.8455693
# bestIteration = 2222
#
# Shrink model to first 2223 iterations.
# 0:	learn: 646.8346770	test: 646.6868084	test1: 624.3830781	best: 624.3830781 (0)	total: 38.9ms	remaining: 6m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 169.2514394
# bestIteration = 1634
#
# Shrink model to first 1635 iterations.
# 0:	learn: 647.9203039	test: 647.7581078	test1: 619.4912424	best: 619.4912424 (0)	total: 42.8ms	remaining: 7m 8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 164.5252701
# bestIteration = 1978
#
# Shrink model to first 1979 iterations.
# 0:	learn: 636.6588240	test: 636.6047642	test1: 663.8877881	best: 663.8877881 (0)	total: 24.9ms	remaining: 4m 9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 160.3489949
# bestIteration = 3037
#
# Shrink model to first 3038 iterations.
# 0:	learn: 643.5144488	test: 643.4250694	test1: 637.5553668	best: 637.5553668 (0)	total: 30.2ms	remaining: 5m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 179.8839774
# bestIteration = 2631
#
# Shrink model to first 2632 iterations.
# 58 번째 모델---------------------------------------------------------------------
# 0:	learn: 228.0746009	test: 227.8171356	test1: 237.0542316	best: 237.0542316 (0)	total: 90.1ms	remaining: 15m 1s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 33.68808177
# bestIteration = 1666
#
# Shrink model to first 1667 iterations.
# 0:	learn: 230.9173135	test: 230.8313878	test1: 226.5361811	best: 226.5361811 (0)	total: 24.6ms	remaining: 4m 6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 37.90274236
# bestIteration = 2014
#
# Shrink model to first 2015 iterations.
# 0:	learn: 229.4497553	test: 229.4510463	test1: 233.2303520	best: 233.2303520 (0)	total: 27.6ms	remaining: 4m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 36.49095921
# bestIteration = 1978
#
# Shrink model to first 1979 iterations.
# 0:	learn: 230.3274009	test: 230.1136183	test1: 229.6069572	best: 229.6069572 (0)	total: 23.7ms	remaining: 3m 57s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 36.6251299
# bestIteration = 1308
#
# Shrink model to first 1309 iterations.
# 0:	learn: 231.4749096	test: 231.3159581	test1: 224.7024764	best: 224.7024764 (0)	total: 40.2ms	remaining: 6m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 34.18503823
# bestIteration = 1819
#
# Shrink model to first 1820 iterations.
# 59 번째 모델---------------------------------------------------------------------
# 0:	learn: 282.9037188	test: 282.9037188	test1: 279.4155086	best: 279.4155086 (0)	total: 39.5ms	remaining: 6m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 146.5194471
# bestIteration = 213
#
# Shrink model to first 214 iterations.
# 0:	learn: 281.4747932	test: 281.4045059	test1: 281.0730925	best: 281.0730925 (0)	total: 58.9ms	remaining: 9m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 153.2229085
# bestIteration = 468
#
# Shrink model to first 469 iterations.
# 0:	learn: 282.4391151	test: 282.4391151	test1: 281.6543869	best: 281.6543869 (0)	total: 55.2ms	remaining: 9m 12s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 158.8121106
# bestIteration = 363
#
# Shrink model to first 364 iterations.
# 0:	learn: 282.3512198	test: 282.3512198	test1: 282.4499266	best: 282.4499266 (0)	total: 56ms	remaining: 9m 20s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 156.1754646
# bestIteration = 352
#
# Shrink model to first 353 iterations.
# 0:	learn: 281.1547177	test: 281.1547177	test1: 286.8537343	best: 286.8537343 (0)	total: 25ms	remaining: 4m 9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 148.585652
# bestIteration = 477
#
# Shrink model to first 478 iterations.
# 60 번째 모델---------------------------------------------------------------------
# 0:	learn: 404.8387613	test: 404.6245777	test1: 406.8347161	best: 406.8347161 (0)	total: 51.3ms	remaining: 8m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 126.9714856
# bestIteration = 1369
#
# Shrink model to first 1370 iterations.
# 0:	learn: 404.8028180	test: 404.4167066	test1: 403.6927947	best: 403.6927947 (0)	total: 34.2ms	remaining: 5m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 133.0337598
# bestIteration = 999
#
# Shrink model to first 1000 iterations.
# 0:	learn: 404.8569319	test: 404.5559344	test1: 402.1672926	best: 402.1672926 (0)	total: 36.3ms	remaining: 6m 3s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 135.8528046
# bestIteration = 887
#
# Shrink model to first 888 iterations.
# 0:	learn: 408.2294877	test: 408.0170243	test1: 388.9686849	best: 388.9686849 (0)	total: 56.9ms	remaining: 9m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 119.1010064
# bestIteration = 1317
#
# Shrink model to first 1318 iterations.
# 0:	learn: 400.4326120	test: 400.2723661	test1: 421.8422390	best: 421.8422390 (0)	total: 68.2ms	remaining: 11m 21s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 135.046875
# bestIteration = 702
#
# Shrink model to first 703 iterations.
# 2021-06-12 10:04:19.199774

# %% [markdown]
# 너무 오래 걸린다. 8시간이 실화냐

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8675.085370
# 1       1 2020-08-25 01  8658.213903
# 2       1 2020-08-25 02  8649.360392
# 3       1 2020-08-25 03  8629.619511
# 4       1 2020-08-25 04  8620.730656
# ...                 ...          ...
# 10075  60 2020-08-31 19  4044.200073
# 10076  60 2020-08-31 20  3928.848304
# 10077  60 2020-08-31 21  3824.677863
# 10078  60 2020-08-31 22  3614.251417
# 10079  60 2020-08-31 23  3349.469956
#
# [10080 rows x 2 columns]

# %%
sub.to_csv('submission/210612_537757-with-catb-catfeatures.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8675.085370
# 1       1 2020-08-25 01  8658.213903
# 2       1 2020-08-25 02  8649.360392
# 3       1 2020-08-25 03  8629.619511
# 4       1 2020-08-25 04  8620.730656
# ...                 ...          ...
# 10075  60 2020-08-31 19  4044.200073
# 10076  60 2020-08-31 20  3928.848304
# 10077  60 2020-08-31 21  3824.677863
# 10078  60 2020-08-31 22  3614.251417
# 10079  60 2020-08-31 23  3349.469956
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_building_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# #### cat_features = [5, 8, 11, 12, 13]

# %%
train_x_1.head(3)
# Out:
#    temp  wind  humid  rain  sunny  month  day  hour  weekday  dayofyear  \
# 0  17.6   2.5   92.0   0.8    0.0      6    1     0        0        153
# 1  17.7   2.9   91.0   0.3    0.0      6    1     1        0        153
# 2  17.5   3.2   91.0   0.0    0.0      6    1     2        0        153
#
#    weekofyear  month_start  month_end  holiday
# 0          23         True      False    False
# 1          23         True      False    False
# 2          23         True      False    False

# %%
cat_features = [5, 8, 11, 12, 13]

# %%
now = datetime.datetime.now()
print(now)

preds = []
fe = []
for i in range(1, 61):
    print(i, '번째 모델---------------------------------------------------------------------')    
    cross = KFold(n_splits=5, shuffle=True, random_state=42)
    folds = []
    for train_idx, valid_idx in cross.split(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)]):
        folds.append((train_idx, valid_idx))
        
    models={}
    for fold in range(5):
        train_idx, valid_idx = folds[fold]
        X_tra = globals()['train_x_{}'.format(i)].iloc[train_idx, :]
        y_tra = globals()['train_y_{}'.format(i)].iloc[train_idx]
        X_val = globals()['train_x_{}'.format(i)].iloc[valid_idx, :]
        y_val = globals()['train_y_{}'.format(i)].iloc[valid_idx]

        model = CatBoostRegressor(learning_rate=0.027, random_state=42, n_estimators=10000, eval_metric='SMAPE')
        model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
                  cat_features=cat_features,
                  early_stopping_rounds=20, verbose=10000)
        models[fold] = model
    
    pred = models[0].predict(globals()['test_x_{}'.format(i)]) / 5
    for k in range(1, 5):
        pred += models[k].predict(globals()['test_x_{}'.format(i)]) / 5
    
    preds.append(pred.tolist())
    fe.append(model.feature_importances_)
    
now = datetime.datetime.now()
print(now)
# Out:
# 2021-06-12 22:53:43.837025
# 1 번째 모델---------------------------------------------------------------------
# 0:	learn: 1.0162849	test: 1.0162849	test1: 0.9849844	best: 0.9849844 (0)	total: 163ms	remaining: 27m 9s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.1882629175
# bestIteration = 1458
#
# Shrink model to first 1459 iterations.
# 0:	learn: 1.0229141	test: 1.0229141	test1: 0.9607566	best: 0.9607566 (0)	total: 33.9ms	remaining: 5m 39s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.1891442829
# bestIteration = 1518
#
# Shrink model to first 1519 iterations.
# 0:	learn: 0.9952902	test: 0.9952902	test1: 1.0680452	best: 1.0680452 (0)	total: 38.4ms	remaining: 6m 23s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.2141606238
# bestIteration = 2366
#
# Shrink model to first 2367 iterations.
# 0:	learn: 1.0085138	test: 1.0085138	test1: 1.0151074	best: 1.0151074 (0)	total: 39.5ms	remaining: 6m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.2019719711
# bestIteration = 2335
#
# Shrink model to first 2336 iterations.
# 0:	learn: 1.0107283	test: 1.0107283	test1: 1.0266958	best: 1.0266958 (0)	total: 32.7ms	remaining: 5m 27s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.1903547704
# bestIteration = 2015
#
# Shrink model to first 2016 iterations.
# 2 번째 모델---------------------------------------------------------------------
# 0:	learn: 21.5118992	test: 21.5118992	test1: 22.3243042	best: 22.3243042 (0)	total: 25.9ms	remaining: 4m 19s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.712157706
# bestIteration = 1276
#
# Shrink model to first 1277 iterations.
# 0:	learn: 21.8650806	test: 21.8650806	test1: 21.6130928	best: 21.6130928 (0)	total: 34ms	remaining: 5m 39s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.778292239
# bestIteration = 1336
#
# Shrink model to first 1337 iterations.
# 0:	learn: 21.7339018	test: 21.7339018	test1: 21.7411819	best: 21.7411819 (0)	total: 37.1ms	remaining: 6m 10s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.858383684
# bestIteration = 1429
#
# Shrink model to first 1430 iterations.
# 0:	learn: 21.5719516	test: 21.5719516	test1: 21.5729260	best: 21.5729260 (0)	total: 43.5ms	remaining: 7m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.904167434
# bestIteration = 2067
#
# Shrink model to first 2068 iterations.
# 0:	learn: 21.7730735	test: 21.7730735	test1: 21.2862891	best: 21.2862891 (0)	total: 42ms	remaining: 6m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.94607317
# bestIteration = 908
#
# Shrink model to first 909 iterations.
# 3 번째 모델---------------------------------------------------------------------
# 0:	learn: 3.7238785	test: 3.7238785	test1: 3.9028558	best: 3.9028558 (0)	total: 41.1ms	remaining: 6m 50s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.054665837
# bestIteration = 1214
#
# Shrink model to first 1215 iterations.
# 0:	learn: 3.8052124	test: 3.8052124	test1: 3.5895712	best: 3.5895712 (0)	total: 28.7ms	remaining: 4m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.8747135829
# bestIteration = 773
#
# Shrink model to first 774 iterations.
# 0:	learn: 3.7449440	test: 3.7449440	test1: 3.9384043	best: 3.9384043 (0)	total: 58.8ms	remaining: 9m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.114878958
# bestIteration = 742
#
# Shrink model to first 743 iterations.
# 0:	learn: 3.7624714	test: 3.7624714	test1: 3.8204029	best: 3.8204029 (0)	total: 28.7ms	remaining: 4m 47s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 1.158647148
# bestIteration = 1537
#
# Shrink model to first 1538 iterations.
# 0:	learn: 3.7831381	test: 3.7831381	test1: 3.6223495	best: 3.6223495 (0)	total: 63.3ms	remaining: 10m 33s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.9198775412
# bestIteration = 1068
#
# Shrink model to first 1069 iterations.
# 4 번째 모델---------------------------------------------------------------------
# 0:	learn: 53.9652066	test: 53.9652066	test1: 56.3541479	best: 56.3541479 (0)	total: 42.8ms	remaining: 7m 8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 13.51800033
# bestIteration = 1075
#
# Shrink model to first 1076 iterations.
# 0:	learn: 54.2484741	test: 54.2484741	test1: 56.1697037	best: 56.1697037 (0)	total: 27.3ms	remaining: 4m 32s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 13.67111076
# bestIteration = 544
#
# Shrink model to first 545 iterations.
# 0:	learn: 54.5274181	test: 54.5274181	test1: 54.0559808	best: 54.0559808 (0)	total: 28.3ms	remaining: 4m 42s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 10.86231937
# bestIteration = 480
#
# Shrink model to first 481 iterations.
# 0:	learn: 55.0546398	test: 55.0546398	test1: 51.0991204	best: 51.0991204 (0)	total: 31.2ms	remaining: 5m 11s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 13.31652961
# bestIteration = 857
#
# Shrink model to first 858 iterations.
# 0:	learn: 54.3012123	test: 54.3012123	test1: 54.6892817	best: 54.6892817 (0)	total: 47.9ms	remaining: 7m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 13.70279749
# bestIteration = 788
#
# Shrink model to first 789 iterations.
# 5 번째 모델---------------------------------------------------------------------
# 0:	learn: 12.3046039	test: 12.3046039	test1: 12.2674227	best: 12.2674227 (0)	total: 42.1ms	remaining: 7m
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.775467066
# bestIteration = 2254
#
# Shrink model to first 2255 iterations.
# 0:	learn: 12.1787767	test: 12.1787767	test1: 12.7012023	best: 12.7012023 (0)	total: 34.6ms	remaining: 5m 46s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.870865001
# bestIteration = 1883
#
# Shrink model to first 1884 iterations.
# 0:	learn: 12.5569254	test: 12.5569254	test1: 11.2018486	best: 11.2018486 (0)	total: 45.1ms	remaining: 7m 30s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.939793085
# bestIteration = 1851
#
# Shrink model to first 1852 iterations.
# 0:	learn: 12.2726560	test: 12.2726560	test1: 12.3082470	best: 12.3082470 (0)	total: 42.7ms	remaining: 7m 6s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.59143394
# bestIteration = 3348
#
# Shrink model to first 3349 iterations.
# 0:	learn: 12.1187369	test: 12.1187369	test1: 12.9934603	best: 12.9934603 (0)	total: 37.6ms	remaining: 6m 15s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.681779947
# bestIteration = 2683
#
# Shrink model to first 2684 iterations.
# 6 번째 모델---------------------------------------------------------------------
# 0:	learn: 51.7979157	test: 51.7979157	test1: 53.3321962	best: 53.3321962 (0)	total: 45.2ms	remaining: 7m 31s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 2.159113184
# bestIteration = 1813
#
# Shrink model to first 1814 iterations.
# 0:	learn: 52.2023943	test: 52.2023943	test1: 53.1842396	best: 53.1842396 (0)	total: 26.9ms	remaining: 4m 29s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 2.17925086
# bestIteration = 2322
#
# Shrink model to first 2323 iterations.
# 0:	learn: 51.8835026	test: 51.8835026	test1: 52.8281496	best: 52.8281496 (0)	total: 30.5ms	remaining: 5m 5s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 2.310229103
# bestIteration = 1676
#
# Shrink model to first 1677 iterations.
# 0:	learn: 51.9044106	test: 51.9044106	test1: 50.9691316	best: 50.9691316 (0)	total: 45.5ms	remaining: 7m 34s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 2.524565674
# bestIteration = 1866
#
# Shrink model to first 1867 iterations.
# 0:	learn: 52.5545336	test: 52.5545336	test1: 50.2593210	best: 50.2593210 (0)	total: 55.5ms	remaining: 9m 14s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 2.604177378
# bestIteration = 2518
#
# Shrink model to first 2519 iterations.
# 7 번째 모델---------------------------------------------------------------------
# 0:	learn: 34.8280826	test: 34.8280826	test1: 35.3225012	best: 35.3225012 (0)	total: 27.5ms	remaining: 4m 35s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 4.1155413
# bestIteration = 1425
#
# Shrink model to first 1426 iterations.
# 0:	learn: 35.1496254	test: 35.1496254	test1: 34.3167006	best: 34.3167006 (0)	total: 51.4ms	remaining: 8m 34s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 4.42317444
# bestIteration = 1149
#
# Shrink model to first 1150 iterations.
# 0:	learn: 34.7552978	test: 34.7552978	test1: 36.0201144	best: 36.0201144 (0)	total: 34ms	remaining: 5m 39s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 4.314022392
# bestIteration = 1724
#
# Shrink model to first 1725 iterations.
# 0:	learn: 34.6009596	test: 34.6009596	test1: 35.3502017	best: 35.3502017 (0)	total: 44.2ms	remaining: 7m 22s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 4.50016039
# bestIteration = 629
#
# Shrink model to first 630 iterations.
# 0:	learn: 35.1769450	test: 35.1769450	test1: 33.5634928	best: 33.5634928 (0)	total: 42ms	remaining: 6m 59s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 4.140477018
# bestIteration = 1468
#
# Shrink model to first 1469 iterations.
# 8 번째 모델---------------------------------------------------------------------
# 0:	learn: 37.6620266	test: 37.6620266	test1: 38.4787734	best: 38.4787734 (0)	total: 41.3ms	remaining: 6m 53s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.063429025
# bestIteration = 1560
#
# Shrink model to first 1561 iterations.
# 0:	learn: 38.0302108	test: 38.0302108	test1: 37.8284974	best: 37.8284974 (0)	total: 33ms	remaining: 5m 30s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.320780863
# bestIteration = 1051
#
# Shrink model to first 1052 iterations.
# 0:	learn: 37.7735422	test: 37.7735422	test1: 38.2821319	best: 38.2821319 (0)	total: 36.9ms	remaining: 6m 8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.241515678
# bestIteration = 2098
#
# Shrink model to first 2099 iterations.
# 0:	learn: 37.5933709	test: 37.5933709	test1: 37.3715117	best: 37.3715117 (0)	total: 52.9ms	remaining: 8m 48s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 3.128406633
# bestIteration = 1556
#
# Shrink model to first 1557 iterations.
# 0:	learn: 37.9861077	test: 37.9861077	test1: 37.1125908	best: 37.1125908 (0)	total: 39.7ms	remaining: 6m 36s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-6c2a4e34cdf4> in <module>
#      20
#      21         model = CatBoostRegressor(learning_rate=0.027, random_state=42, n_estimators=10000, eval_metric='SMAPE')
# ---> 22         model.fit(X_tra, y_tra, eval_set=[(X_tra, y_tra), (X_val, y_val)],
#      23                   cat_features=cat_features,
#      24                   early_stopping_rounds=20, verbose=10000)
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    5084             self._check_is_regressor_loss(params['loss_function'])
#    5085
# -> 5086         return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#    5087                          use_best_model, eval_set, verbose, logging_level, plot, column_description,
#    5088                          verbose_eval, metric_period, silent, early_stopping_rounds,
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model)
#    1916
#    1917         with log_fixup(), plot_wrapper(plot, [_get_train_dir(self.get_params())]):
# -> 1918             self._train(
#    1919                 train_pool,
#    1920                 train_params["eval_sets"],
#
# ~\miniconda3\envs\wyatt38\lib\site-packages\catboost\core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1364
#    1365     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1366         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1367         self._set_trained_model_attributes()
#    1368
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:

# %%
preds = sum(preds, [])

# %%
sub.answer = preds

# %%
sub

# %%
sub.to_csv('submission/210612_537757-with-catb-catfeatures.csv', index=False)
sub
# Out:
#           num_date_time       answer
# 0       1 2020-08-25 00  8675.085370
# 1       1 2020-08-25 01  8658.213903
# 2       1 2020-08-25 02  8649.360392
# 3       1 2020-08-25 03  8629.619511
# 4       1 2020-08-25 04  8620.730656
# ...                 ...          ...
# 10075  60 2020-08-31 19  4044.200073
# 10076  60 2020-08-31 20  3928.848304
# 10077  60 2020-08-31 21  3824.677863
# 10078  60 2020-08-31 22  3614.251417
# 10079  60 2020-08-31 23  3349.469956
#
# [10080 rows x 2 columns]

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_building_60.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## 변수 선택

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_x_{}'.format(i)] = train.loc[train.num == i, ~train.columns.isin(['target',
                                                                                      'num',
                                                                                      'cooler',
                                                                                      'solar'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_y_{}'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_x_{}'.format(i)] = test.loc[test.num == i, ~test.columns.isin(['num',
                                                                                  'cooler',
                                                                                  'solar'])]

# %%
train_x_1.head()
# Out:
#    temp  wind  humid  rain  sunny  month  day  hour  weekday  dayofyear  \
# 0  17.6   2.5   92.0   0.8    0.0      6    1     0        0        153
# 1  17.7   2.9   91.0   0.3    0.0      6    1     1        0        153
# 2  17.5   3.2   91.0   0.0    0.0      6    1     2        0        153
# 3  17.1   3.2   91.0   0.0    0.0      6    1     3        0        153
# 4  17.0   3.3   92.0   0.0    0.0      6    1     4        0        153
#
#    weekofyear  month_start  month_end  holiday
# 0          23         True      False    False
# 1          23         True      False    False
# 2          23         True      False    False
# 3          23         True      False    False
# 4          23         True      False    False

# %%
preds = []
fe = []
oob_scores = []
for i in tqdm(range(1, 61)):
    rf = RandomForestRegressor(random_state=42, oob_score=True)
    rf.fit(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)])
    pred = rf.predict(globals()['test_x_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(rf.feature_importances_)
    oob_scores.append(rf.oob_score_)
    
np.sum(oob_scores)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:39<00:00,  1.52it/s]
# 57.189455797322154

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_x_1.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_x_{}'.format(i)] = train.loc[train.num == i, ~train.columns.isin(['target',
                                                                                      'num',
                                                                                      'cooler',
                                                                                      'solar',
                                                                                      'month_end',
                                                                                      'month_start'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_y_{}'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_x_{}'.format(i)] = test.loc[test.num == i, ~test.columns.isin(['num',
                                                                                  'cooler',
                                                                                  'solar',
                                                                                  'month_end',
                                                                                  'month_start'])]

# %%
train_x_1.head()
# Out:
#    temp  wind  humid  rain  sunny  month  day  hour  weekday  dayofyear  \
# 0  17.6   2.5   92.0   0.8    0.0      6    1     0        0        153
# 1  17.7   2.9   91.0   0.3    0.0      6    1     1        0        153
# 2  17.5   3.2   91.0   0.0    0.0      6    1     2        0        153
# 3  17.1   3.2   91.0   0.0    0.0      6    1     3        0        153
# 4  17.0   3.3   92.0   0.0    0.0      6    1     4        0        153
#
#    weekofyear  holiday
# 0          23    False
# 1          23    False
# 2          23    False
# 3          23    False
# 4          23    False

# %%
preds = []
fe = []
oob_scores = []
for i in tqdm(range(1, 61)):
    rf = RandomForestRegressor(random_state=42, oob_score=True)
    rf.fit(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)])
    pred = rf.predict(globals()['test_x_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(rf.feature_importances_)
    oob_scores.append(rf.oob_score_)
    
np.sum(oob_scores)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:38<00:00,  1.57it/s]
# 57.18974721750349

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_x_1.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()

# %%
for i in range(1, 61):
    # 빌딩별로 train_x을 만듭니다.
    globals()['train_x_{}'.format(i)] = train.loc[train.num == i, ~train.columns.isin(['target',
                                                                                      'num',
                                                                                      'cooler',
                                                                                      'solar',
                                                                                      'month_end',
                                                                                      'month_start',
                                                                                      'rain',
                                                                                      'wind',
                                                                                      'month'])]
    
    # 빌딩별로 train_y 를 만듭니다.
    globals()['train_y_{}'.format(i)] = train.loc[train.num == i, 'target']
    
    # 빌딩별로 test_x 를 만듭니다.
    globals()['test_x_{}'.format(i)] = test.loc[test.num == i, ~test.columns.isin(['num',
                                                                                  'cooler',
                                                                                  'solar',
                                                                                  'month_end',
                                                                                  'month_start',
                                                                                      'rain',
                                                                                      'wind',
                                                                                      'month'])]

# %%
train_x_1.head()
# Out:
#    temp  humid  sunny  day  hour  weekday  dayofyear  weekofyear  holiday
# 0  17.6   92.0    0.0    1     0        0        153          23    False
# 1  17.7   91.0    0.0    1     1        0        153          23    False
# 2  17.5   91.0    0.0    1     2        0        153          23    False
# 3  17.1   91.0    0.0    1     3        0        153          23    False
# 4  17.0   92.0    0.0    1     4        0        153          23    False

# %%
test_x_1.head()
# Out:
#    temp  humid  sunny  day  hour  weekday  dayofyear  weekofyear  holiday
# 0  27.8   74.0    0.0   25     0        1        238          35    False
# 1  27.6   75.3    0.0   25     1        1        238          35    False
# 2  27.5   76.7    0.0   25     2        1        238          35    False
# 3  27.3   78.0    0.0   25     3        1        238          35    False
# 4  26.9   79.7    0.0   25     4        1        238          35    False

# %%
preds = []
fe = []
oob_scores = []
for i in tqdm(range(1, 61)):
    rf = RandomForestRegressor(random_state=42, oob_score=True)
    rf.fit(globals()['train_x_{}'.format(i)], globals()['train_y_{}'.format(i)])
    pred = rf.predict(globals()['test_x_{}'.format(i)])
    preds.append(pred.tolist())
    fe.append(rf.feature_importances_)
    oob_scores.append(rf.oob_score_)
    
np.sum(oob_scores)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:32<00:00,  1.85it/s]
# 57.29774610418327

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plt.rcParams["font.size"] = "14"

fe_avg = pd.DataFrame(np.mean(fe, axis=0),
                      index=train_x_1.columns, columns=['fe']).sort_values(by=['fe'], ascending=False)

plt.figure(figsize=(12, 5))
plots = sns.barplot(fe_avg.fe, y=fe_avg.index)

# Annotate every single Bar with its value, based on it's width           
for bar in plots.patches:
    width = bar.get_width()
    plt.text(0.015+ bar.get_width(),
             bar.get_y() + 0.5 * bar.get_height(),
             '{:.3f}'.format(width),
             ha='center', va='center')

plt.show()
